# %% [markdown]
# # Classification of Malicious URL using Deep Learning via Keras

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings

import tensorflow as tf
from tensorflow import keras
from keras import layers, models
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier, KerasRegressor

warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

np.random.seed(42)
tf.random.set_seed(42)

# %%
# mount the colab
from google.colab import drive
drive.mount('/content/drive')

# For saving and retrieving the trained model
WORKSPACE_PATH = "/content/drive/MyDrive/Colab Notebooks/models/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
WORKSPACE_PATH
# Out:
# '/content/drive/MyDrive/Colab Notebooks/models/'

# %% [markdown]
# # Load the dataset

# %%
# Read the dataset
url = 'https://raw.githubusercontent.com/quickheaven/scs-3546-deep-learning/master/datasets/'

X_train = pd.read_csv(url + 'X_train.csv', index_col=0)
X_test =pd.read_csv(url + 'X_test.csv', index_col=0)

y_train =pd.read_csv(url + 'y_train.csv', index_col=0)
y_test = pd.read_csv(url + 'y_test.csv', index_col=0)

# %%
y_train_dummy = to_categorical(y_train)
y_test_dummy = to_categorical(y_test)

# %% [markdown]
# # Training and Tuning Model
#
# The training and tuning of model is divided into three main experiments. Tuning of Deep Network, Tuning the Back Propagation and last is the Overfitting Management.
#
# The first step before proceeding to other experiments is Tuning the Neural Network. These includes determining first the epoch and batch size to use, the number of hidden layers to add, the number of nodes in each layer, choosing the activation function and the weight initializer.
#
# The second part is Tuning the Back Propagation. It involves whether to use Batch normalization or not, finding the right Optimizers and its Learning Rates.
#
# Lastly is the Overfitting Management, I used Regularation and Dropout as part of the experiment.
# \
# \

# %%
def get_base_model_config():
  """
  This function returns the based model configuration for the experiments.

  Parameters
  ----------
  None

  Returns
  ----------
  dict - The dictionary containing the based model configuration.
  """

  early_stopping_callback = EarlyStopping(monitor='val_accuracy', mode='max', patience=5, restore_best_weights=True)
  callbacks = [early_stopping_callback]

  model_config = {
      "model_name": None,
      "input_dim": 51,
      "epochs": 200,
      "validation_split": 0.20,
      "callbacks": callbacks,
      "batch_size": 32,
      "hidden_activation": "relu",
      "loss": "categorical_crossentropy",
      "weights_initializer": "random_normal",
      "output_nodes": 5, # TODO
      "output_activation": "softmax",
      "metrics": ['accuracy'],
      "normalization": None,
      "optimizer": "adam",
      "learning_rate": 0.001,
      "custom_layers": list(),
      "is_save_model": False,
      "workspace_path": WORKSPACE_PATH
  }
  return model_config

# %%
def get_optimizer(optimizer_name, learning_rate):
  """
  (str. float) -> keras.optimizers

  This method returns the optimizer that will be use in the experiment.

  Parameters
  ----------
  optimizer_name - The name of the optimizer to use in the experiment. values are adagrad, rmsprop, adam and None.
  learning_rate - The rate of learning to use in the optimizer.

  Returns
  ----------
  keras.optimizer - The keras optimizer object.
  """
  optimizer=None
  if optimizer_name == 'adagrad':
      optimizer = keras.optimizers.Adagrad(learning_rate=learning_rate)
  elif 'rmsprop':
      optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)
  elif'adam' :
      optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
  else :
      optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

  return optimizer

# %%
def create_and_run_model(model_config, X, y):

  # Build the new model
  model = Sequential(layers=model_config['custom_layers'], name=model_config['model_name'])
  model.summary()

  optimizer = get_optimizer(model_config["optimizer"], model_config["learning_rate"])

  # Compile the model
  model.compile(optimizer=optimizer,
                loss=model_config['loss'],
                metrics=model_config['metrics'])

  # Fit the model
  history = model.fit(X, y,
                      batch_size=model_config['batch_size'],
                      callbacks=model_config['callbacks'],
                      epochs=model_config['epochs'],
                      validation_split=model_config['validation_split'])

  if True == model_config['is_save_model']:
    model_file = str(model_config['workspace_path']) + str(model_config['model_name']) + '.h5'
    model.save(model_file)

  return history

# %%
def plot_accuracy_measures(accuracy_measures, title):

    import matplotlib.pyplot as plt

    plt.figure(figsize=(8, 5))
    for experiment in accuracy_measures.keys():
        plt.plot(accuracy_measures[experiment],
                 label=experiment,
                    linewidth=3)

    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

# %%
def plot_learning_curves(history, title):
  # plot curves for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Learning Curves ' + title)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Validation'], loc='upper left')
  plt.plot(figsize=(8, 5))
  plt.grid(True)
  plt.show()

# %% [markdown]
# ## Tuning Deep Neural Network

# %% [markdown]
# ### Epoch and Batch size tuning
# Figure out the right number of batches and epochs first, and then use that for further experimentation.
#
# **Batch Size:** Experiment for the right size, batch size of 32 found most optimal for most use cases.
#
# **Epoch:** Choose the earliest value when accuracy stabilizers.

# %%
accuracy_measures = {}
model_config = get_base_model_config()

batch_sizes = [32, 64, 128]

for size in batch_sizes:

  model_config['batch_size'] = size

  custom_layers = [
      layers.Dense(32, activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];
  model_name = 'Epoch_and_batch_size_' + str(size)
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Epoch_and_batch_size_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 32)                1664
#
#  dense_16 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 1829 (7.14 KB)
# Trainable params: 1829 (7.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4757 - accuracy: 0.8285 - val_loss: 0.4931 - val_accuracy: 0.8282
# Epoch 23/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4688 - accuracy: 0.8323 - val_loss: 0.4803 - val_accuracy: 0.8278
# Epoch 24/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4621 - accuracy: 0.8341 - val_loss: 0.4701 - val_accuracy: 0.8316
# Epoch 25/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4563 - accuracy: 0.8359 - val_loss: 0.4652 - val_accuracy: 0.8379
# Epoch 26/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4504 - accuracy: 0.8371 - val_loss: 0.4610 - val_accuracy: 0.8329
# Epoch 27/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4452 - accuracy: 0.8397 - val_loss: 0.4545 - val_accuracy: 0.8396
# Epoch 28/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4400 - accuracy: 0.8430 - val_loss: 0.4548 - val_accuracy: 0.8392
# Epoch 29/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4354 - accuracy: 0.8440 - val_loss: 0.4567 - val_accuracy: 0.8369
# Epoch 30/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4309 - accuracy: 0.8440 - val_loss: 0.4529 - val_accuracy: 0.8367
# Epoch 31/200
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4268 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8481
# Epoch 32/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4213 - accuracy: 0.8481 - val_loss: 0.4342 - val_accuracy: 0.8487
# Epoch 33/200
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4178 - accuracy: 0.8504 - val_loss: 0.4339 - val_accuracy: 0.8447
# Epoch 34/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4131 - accuracy: 0.8524 - val_loss: 0.4251 - val_accuracy: 0.8498
# Epoch 35/200
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4088 - accuracy: 0.8543 - val_loss: 0.4364 - val_accuracy: 0.8426
# Epoch 36/200
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4059 - accuracy: 0.8556 - val_loss: 0.4312 - val_accuracy: 0.8434
# Epoch 37/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4016 - accuracy: 0.8563 - val_loss: 0.4278 - val_accuracy: 0.8453
# Epoch 38/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3990 - accuracy: 0.8594 - val_loss: 0.4152 - val_accuracy: 0.8546
# Epoch 39/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3956 - accuracy: 0.8600 - val_loss: 0.4117 - val_accuracy: 0.8481
# Epoch 40/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3917 - accuracy: 0.8610 - val_loss: 0.4222 - val_accuracy: 0.8483
# Epoch 41/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3883 - accuracy: 0.8629 - val_loss: 0.4137 - val_accuracy: 0.8502
# Epoch 42/200
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3855 - accuracy: 0.8647 - val_loss: 0.4135 - val_accuracy: 0.8522
# Epoch 43/200
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3834 - accuracy: 0.8639 - val_loss: 0.4066 - val_accuracy: 0.8540
# Model: "Epoch_and_batch_size_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 32)                1664
#
#  dense_18 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 1829 (7.14 KB)
# Trainable params: 1829 (7.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1
# %%
accuracy_measures_batch_epoch = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Batch Size and Epoch")

# %% [markdown]
# For this use case, it seems there is no benefits on increasing the batch size further. Moving forward I am just going to use the batch size of 32.\
# Meanwhile, the earliest epoch where stabilization happens was 50.

# %%
model_config['batch_size'] = 32
model_config['epochs'] = 50

# %% [markdown]
# ### Hidden layers tuning
#
# One of the key model architecture hyperparameters is the number of hidden layers. As the number of layers increases, it increases the possibility of learning complex relationships between features and target variables, but it will also increase the cost and time needed for both training and inference. It is also has the risk of overfitting the training set.
#
# A **value of two** has been sufficient for simple problems. It is recommended to increase the number of layers only based on experimentation if the set accuracy levels are not achieved. Otherwise, additional layers will take resources and time without providing any additional value.

# %%
model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50

accuracy_measures = {}

# reused the previous model config from previous experiment.
# but on this case only increase the number of layers

# I will start small by checking if one or two nodes is enough to get a good result.
layer_list = []
for hidden_layer_count in range(1,3):
  custom_layers = []

  # Simply use 32 nodes per layer for now.

  # Input
  if hidden_layer_count == 1:
    custom_layers.append(layers.Dense(32, activation=model_config['hidden_activation'], input_dim=model_config['input_dim']))
  else:
  # Additional Layers
    custom_layers.append(layers.Dense(32, activation=model_config['hidden_activation'], input_dim=model_config['input_dim']))
    for i in range(1, hidden_layer_count):
      custom_layers.append(layers.Dense(32, activation=model_config['hidden_activation']))

  # Output layers
  custom_layers.append(layers.Dense(model_config['output_nodes'], activation=model_config['output_activation']))

  model_name = 'Layers_' + str(hidden_layer_count)
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Layers_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 32)                1664
#
#  dense_31 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 1829 (7.14 KB)
# Trainable params: 1829 (7.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.2125 - accuracy: 0.5740 - val_loss: 0.9751 - val_accuracy: 0.6667
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9019 - accuracy: 0.6868 - val_loss: 0.8353 - val_accuracy: 0.7024
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8087 - accuracy: 0.7104 - val_loss: 0.7693 - val_accuracy: 0.7195
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7516 - accuracy: 0.7345 - val_loss: 0.7277 - val_accuracy: 0.7421
# Epoch 5/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.7084 - accuracy: 0.7445 - val_loss: 0.6845 - val_accuracy: 0.7557
# Epoch 6/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.6715 - accuracy: 0.7596 - val_loss: 0.6526 - val_accuracy: 0.7659
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6413 - accuracy: 0.7689 - val_loss: 0.6280 - val_accuracy: 0.7726
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6154 - accuracy: 0.7799 - val_loss: 0.6072 - val_accuracy: 0.7777
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0
50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3947 - accuracy: 0.8652 - val_loss: 0.4162 - val_accuracy: 0.8607
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3906 - accuracy: 0.8666 - val_loss: 0.4074 - val_accuracy: 0.8630
# Epoch 35/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3865 - accuracy: 0.8661 - val_loss: 0.4169 - val_accuracy: 0.8581
# Epoch 36/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3842 - accuracy: 0.8683 - val_loss: 0.4188 - val_accuracy: 0.8587
# Epoch 37/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3804 - accuracy: 0.8695 - val_loss: 0.4122 - val_accuracy: 0.8583
# Epoch 38/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3782 - accuracy: 0.8701 - val_loss: 0.3975 - val_accuracy: 0.8652
# Epoch 39/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3749 - accuracy: 0.8717 - val_loss: 0.3982 - val_accuracy: 0.8646
# Epoch 40/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3715 - accuracy: 0.8729 - val_loss: 0.4019 - val_accuracy: 0.8632
# Epoch 41/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3689 - accuracy: 0.8734 - val_loss: 0.4023 - val_accuracy: 0.8652
# Epoch 42/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3660 - accuracy: 0.8752 - val_loss: 0.3967 - val_accuracy: 0.8597
# Epoch 43/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3636 - accuracy: 0.8761 - val_loss: 0.3995 - val_accuracy: 0.8652
# Model: "Layers_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 32)                1664
#
#  dense_33 (Dense)            (None, 32)                1056
#
#  dense_34 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 2885 (11.27 KB)
# Trainable params: 2885 (11.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.1371 - accuracy: 0.5953 - val_loss: 0.8700 - val_accuracy: 0.6816
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8148 - accuracy: 0.7053 - val_loss: 0.7572 - val_accuracy: 0.7256
# Epoch 3/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.7261 - accuracy: 0.7309 - val_loss: 0.6883 - val_accuracy: 0.7357
# Epoch 4/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.6563 - accuracy: 0.7578 - val_loss: 0.6294 - val_accuracy: 0.7700
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6064 - accuracy: 0.7754 - val_loss: 0.5884 - val_accuracy: 0.7750
# Epoch 6/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5693 - accuracy: 0.7904 - val_loss: 0.5534 - val_accuracy: 0.8019
# Epoch 7/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.8050 - val_loss: 0.5312 - val_accuracy: 0.8158
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5154 - accuracy: 0.8139 - val_loss: 0.5097 - val_accuracy: 0.8219
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4972 - accuracy: 0.8198 - val_loss: 0.4977 - val_accuracy: 0.8257
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4803 - accuracy: 0.8262 - val_loss: 0.4897 - val_accuracy: 0.8259
# Epoch 11/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4667 - accuracy: 0.8295 - val_loss: 0.4581 - val_accuracy: 0.8371
# Epoch 12/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4520 - accuracy: 0.8357 - val_loss: 0.4538 - val_accuracy: 0.8367
# Epoch 13/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4405 - accuracy: 0.8418 - val_loss: 0.4328 - val_accuracy: 0.8487
# Epoch 14/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4299 - accuracy: 0.8429 - val_loss: 0.4301 - val_accuracy: 0.8398
# Epoch 15/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4191 - accuracy: 0.8479 - val_loss: 0.4161 - val_accuracy: 0.8522
# Epoch 16/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4089 - accuracy: 0.8535 - val_loss: 0.4226 - val_accuracy: 0.8555
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3996 - accuracy: 0.8561 - val_loss: 0.4262 - val_accuracy: 0.8553
# Epoch 18/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3919 - accuracy: 0.8596 - val_loss: 0.4014 - val_accuracy: 0.8583
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3852 - accuracy: 0.8619 - val_loss: 0.4003 - val_accuracy: 0.8664
# Epoch 20/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3772 - accuracy: 0.8654 - val_loss: 0.3925 - val_accuracy: 0.8608
# Epoch 21/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3715 - accuracy: 0.8664 - val_loss: 0.3767 - val_accuracy: 0.8665
# Epoch 22/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3636 - accuracy: 0.8707 - val_loss: 0.3821 - val_accuracy: 0.8667
# Epoch 23/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3571 - accuracy: 0.8717 - val_loss: 0.3766 - val_accuracy: 0.8679
# Epoch 24/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3525 - accuracy: 0.8739 - val_loss: 0.3665 - val_accuracy: 0.8728
# Epoch 25/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3471 - accuracy: 0.8778 - val_loss: 0.3652 - val_accuracy: 0.8756
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3411 - accuracy: 0.8772 - val_loss: 0.3592 - val_accuracy: 0.8807
# Epoch 27/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3363 - accuracy: 0.8805 - val_loss: 0.3448 - val_accuracy: 0.8779
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3319 - accuracy: 0.8819 - val_loss: 0.3413 - val_accuracy: 0.8815
# Epoch 29/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3271 - accuracy: 0.8838 - val_loss: 0.3907 - val_accuracy: 0.8646
# Epoch 30/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3223 - accuracy: 0.8863 - val_loss: 0.3457 - val_accuracy: 0.8809
# Epoch 31/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3201 - accuracy: 0.8883 - val_loss: 0.3322 - val_accuracy: 0.8856
# Epoch 32/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3149 - accuracy: 0.8892 - val_loss: 0.3292 - val_accuracy: 0.8880
# Epoch 33/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3120 - accuracy: 0.8918 - val_loss: 0.3352 - val_accuracy: 0.8817
# Epoch 34/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3065 - accuracy: 0.8925 - val_loss: 0.3335 - val_accuracy: 0.8852
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3033 - accuracy: 0.8945 - val_loss: 0.3388 - val_accuracy: 0.8791
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3015 - accuracy: 0.8947 - val_loss: 0.3281 - val_accuracy: 0.8842
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2974 - accuracy: 0.8963 - val_loss: 0.3414 - val_accuracy: 0.8829
# Model: "Layers_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 32)                1664
#
#  dense_36 (Dense)            (None, 32)                1056
#
#  dense_37 (Dense)            (None, 32)                1056
#
#  dense_38 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 3941 (15.39 KB)
# Trainable params: 3941 (15.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.0792 - accuracy: 0.6151 - val_loss: 0.8219 - val_accuracy: 0.7081
# Epoch 2/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.7666 - accuracy: 0.7245 - val_loss: 0.6960 - val_accuracy: 0.7498
# Epoch 3/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.6563 - accuracy: 0.7601 - val_loss: 0.6014 - val_accuracy: 0.7834
# Epoch 4/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.5799 - accuracy: 0.7917 - val_loss: 0.5371 - val_accuracy: 0.8107
# Epoch 5/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.5272 - accuracy: 0.8098 - val_loss: 0.5035 - val_accuracy: 0.8206
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4865 - accuracy: 0.8283 - val_loss: 0.4667 - val_accuracy: 0.8394
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4566 - accuracy: 0.8397 - val_loss: 0.4436 - val_accuracy: 0.8491
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4342 - accuracy: 0.8464 - val_loss: 0.4176 - val_accuracy: 0.8593
# Epoch 9/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4158 - accuracy: 0.8537 - val_loss: 0.4531 - val_accuracy: 0.8487
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3984 - accuracy: 0.8624 - val_loss: 0.4001 - val_accuracy: 0.8669
# Epoch 11/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3862 - accuracy: 0.8673 - val_loss: 0.3791 - val_accuracy: 0.8736
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3745 - accuracy: 0.8695 - val_loss: 0.3738 - val_accuracy: 0.8740
# Epoch 13/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3633 - accuracy: 0.8747 - val_loss: 0.3659 - val_accuracy: 0.8787
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3538 - accuracy: 0.8759 - val_loss: 0.3714 - val_accuracy: 0.8766
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3467 - accuracy: 0.8794 - val_loss: 0.3664 - val_accuracy: 0.8807
# Epoch 16/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3392 - accuracy: 0.8825 - val_loss: 0.3636 - val_accuracy: 0.8762
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3316 - accuracy: 0.8854 - val_loss: 0.3849 - val_accuracy: 0.8746
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3264 - accuracy: 0.8863 - val_loss: 0.3391 - val_accuracy: 0.8895
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3215 - accuracy: 0.8876 - val_loss: 0.3561 - val_accuracy: 0.8817
# Epoch 20/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3150 - accuracy: 0.8911 - val_loss: 0.3446 - val_accuracy: 0.8846
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3102 - accuracy: 0.8946 - val_loss: 0.3391 - val_accuracy: 0.8895
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3054 - accuracy: 0.8949 - val_loss: 0.3200 - val_accuracy: 0.8947
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2987 - accuracy: 0.8964 - val_loss: 0.3348 - val_accuracy: 0.8952
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2958 - accuracy: 0.8987 - val_loss: 0.3140 - val_accuracy: 0.8990
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2921 - accuracy: 0.8997 - val_loss: 0.3383 - val_accuracy: 0.8862
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2879 - accuracy: 0.9017 - val_loss: 0.3211 - val_accuracy: 0.8968
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2831 - accuracy: 0.9027 - val_loss: 0.3097 - val_accuracy: 0.8978
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2805 - accuracy: 0.9015 - val_loss: 0.3063 - val_accuracy: 0.9002
# Epoch 29/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2788 - accuracy: 0.9043 - val_loss: 0.3824 - val_accuracy: 0.8730
# Epoch 30/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2727 - accuracy: 0.9065 - val_loss: 0.3074 - val_accuracy: 0.8990
# Epoch 31/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2717 - accuracy: 0.9087 - val_loss: 0.3072 - val_accuracy: 0.8990
# Epoch 32/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2682 - accuracy: 0.9081 - val_loss: 0.3294 - val_accuracy: 0.8907
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2638 - accuracy: 0.9091 - val_loss: 0.3005 - val_accuracy: 0.9019
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2601 - accuracy: 0.9100 - val_loss: 0.3342 - val_accuracy: 0.8954
# Epoch 35/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2563 - accuracy: 0.9126 - val_loss: 0.2946 - val_accuracy: 0.9037
# Epoch 36/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2541 - accuracy: 0.9139 - val_loss: 0.2870 - val_accuracy: 0.9080
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2522 - accuracy: 0.9146 - val_loss: 0.2980 - val_accuracy: 0.9055
# Epoch 38/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2502 - accuracy: 0.9152 - val_loss: 0.2868 - val_accuracy: 0.9127
# Epoch 39/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2473 - accuracy: 0.9152 - val_loss: 0.2808 - val_accuracy: 0.9119
# Epoch 40/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2431 - accuracy: 0.9179 - val_loss: 0.2932 - val_accuracy: 0.9070
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2421 - accuracy: 0.9187 - val_loss: 0.2916 - val_accuracy: 0.9025
# Epoch 42/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2379 - accuracy: 0.9191 - val_loss: 0.2779 - val_accuracy: 0.9147
# Epoch 43/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2352 - accuracy: 0.9186 - val_loss: 0.2758 - val_accuracy: 0.9137
# Epoch 44/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2337 - accuracy: 0.9217 - val_loss: 0.2788 - val_accuracy: 0.9064
# Epoch 45/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2302 - accuracy: 0.9218 - val_loss: 0.3078 - val_accuracy: 0.9006
# Epoch 46/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2302 - accuracy: 0.9226 - val_loss: 0.2754 - val_accuracy: 0.9125
# Epoch 47/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2279 - accuracy: 0.9249 - val_loss: 0.2698 - val_accuracy: 0.9149
# Epoch 48/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2223 - accuracy: 0.9252 - val_loss: 0.3198 - val_accuracy: 0.8937
# Epoch 49/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2241 - accuracy: 0.9228 - val_loss: 0.3158 - val_accuracy: 0.8996
# Epoch 50/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2211 - accuracy: 0.9257 - val_loss: 0.3136 - val_accuracy: 0.8919
# Model: "Layers_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_39 (Dense)            (None, 32)                1664
#
#  dense_40 (Dense)            (None, 32)                1056
#
#  dense_41 (Dense)            (None, 32)                1056
#
#  dense_42 (Dense)            (None, 32)                1056
#
#  dense_43 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 4997 (19.52 KB)
# Trainable params: 4997 (19.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 1.0211 - accuracy: 0.6228 - val_loss: 0.7749 - val_accuracy: 0.7105
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7303 - accuracy: 0.7349 - val_loss: 0.6440 - val_accuracy: 0.7667
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.6203 - accuracy: 0.7764 - val_loss: 0.5688 - val_accuracy: 0.7985
# Epoch 4/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.5486 - accuracy: 0.8083 - val_loss: 0.5019 - val_accuracy: 0.8219
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5076 - accuracy: 0.8174 - val_loss: 0.4903 - val_accuracy: 0.8257
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4762 - accuracy: 0.8295 - val_loss: 0.4473 - val_accuracy: 0.8438
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4505 - accuracy: 0.8413 - val_loss: 0.4307 - val_accuracy: 0.8455
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4275 - accuracy: 0.8482 - val_loss: 0.4163 - val_accuracy: 0.8587
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4118 - accuracy: 0.8566 - val_loss: 0.4943 - val_accuracy: 0.8327
# Epoch 10/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3946 - accuracy: 0.8623 - val_loss: 0.4048 - val_accuracy: 0.8673
# Epoch 11/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3794 - accuracy: 0.8698 - val_loss: 0.3740 - val_accuracy: 0.8695
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3671 - accuracy: 0.8732 - val_loss: 0.3581 - val_accuracy: 0.8770
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3532 - accuracy: 0.8783 - val_loss: 0.3537 - val_accuracy: 0.8750
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3431 - accuracy: 0.8810 - val_loss: 0.3563 - val_accuracy: 0.8766
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3339 - accuracy: 0.8866 - val_loss: 0.3501 - val_accuracy: 0.8821
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3252 - accuracy: 0.8885 - val_loss: 0.3583 - val_accuracy: 0.8764
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3180 - accuracy: 0.8902 - val_loss: 0.3644 - val_accuracy: 0.8787
# Epoch 18/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3110 - accuracy: 0.8939 - val_loss: 0.3193 - val_accuracy: 0.8888
# Epoch 19/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3062 - accuracy: 0.8944 - val_loss: 0.3237 - val_accuracy: 0.8923
# Epoch 20/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2979 - accuracy: 0.8956 - val_loss: 0.3476 - val_accuracy: 0.8809
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2950 - accuracy: 0.8985 - val_loss: 0.3036 - val_accuracy: 0.8970
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2873 - accuracy: 0.9005 - val_loss: 0.3107 - val_accuracy: 0.8929
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2817 - accuracy: 0.9026 - val_loss: 0.2968 - val_accuracy: 0.9015
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2773 - accuracy: 0.9063 - val_loss: 0.2823 - val_accuracy: 0.9047
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2716 - accuracy: 0.9073 - val_loss: 0.2899 - val_accuracy: 0.8990
# Epoch 26/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2668 - accuracy: 0.9065 - val_loss: 0.3056 - val_accuracy: 0.9013
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2621 - accuracy: 0.9103 - val_loss: 0.2758 - val_accuracy: 0.9070
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2583 - accuracy: 0.9091 - val_loss: 0.2718 - val_accuracy: 0.9086
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2560 - accuracy: 0.9127 - val_loss: 0.3085 - val_accuracy: 0.8990
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2496 - accuracy: 0.9138 - val_loss: 0.3120 - val_accuracy: 0.8949
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2462 - accuracy: 0.9148 - val_loss: 0.2920 - val_accuracy: 0.9027
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2452 - accuracy: 0.9169 - val_loss: 0.3134 - val_accuracy: 0.8943
# Epoch 33/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2412 - accuracy: 0.9164 - val_loss: 0.2810 - val_accuracy: 0.9135
# Epoch 34/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2367 - accuracy: 0.9188 - val_loss: 0.3171 - val_accuracy: 0.8964
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2315 - accuracy: 0.9214 - val_loss: 0.2650 - val_accuracy: 0.9163
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2310 - accuracy: 0.9210 - val_loss: 0.2735 - val_accuracy: 0.9112
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2257 - accuracy: 0.9226 - val_loss: 0.2667 - val_accuracy: 0.9133
# Epoch 38/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2241 - accuracy: 0.9231 - val_loss: 0.2580 - val_accuracy: 0.9153
# Epoch 39/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2177 - accuracy: 0.9249 - val_loss: 0.3112 - val_accuracy: 0.9004
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2142 - accuracy: 0.9263 - val_loss: 0.2578 - val_accuracy: 0.9137
# Model: "Layers_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_44 (Dense)            (None, 32)                1664
#
#  dense_45 (Dense)            (None, 32)                1056
#
#  dense_46 (Dense)            (None, 32)                1056
#
#  dense_47 (Dense)            (None, 32)                1056
#
#  dense_48 (Dense)            (None, 32)                1056
#
#  dense_49 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 6053 (23.64 KB)
# Trainable params: 6053 (23.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 1.0215 - accuracy: 0.6157 - val_loss: 0.7699 - val_accuracy: 0.7174
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7390 - accuracy: 0.7254 - val_loss: 0.6565 - val_accuracy: 0.7604
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6302 - accuracy: 0.7697 - val_loss: 0.5601 - val_accuracy: 0.8044
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.8081 - val_loss: 0.4856 - val_accuracy: 0.8288
# Epoch 5/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4832 - accuracy: 0.8272 - val_loss: 0.4513 - val_accuracy: 0.8430
# Epoch 6/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4400 - accuracy: 0.8424 - val_loss: 0.4447 - val_accuracy: 0.8418
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4068 - accuracy: 0.8583 - val_loss: 0.3947 - val_accuracy: 0.8703
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3836 - accuracy: 0.8699 - val_loss: 0.3848 - val_accuracy: 0.8673
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3651 - accuracy: 0.8745 - val_loss: 0.4281 - val_accuracy: 0.8516
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3498 - accuracy: 0.8790 - val_loss: 0.3468 - val_accuracy: 0.8870
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3360 - accuracy: 0.8860 - val_loss: 0.3294 - val_accuracy: 0.8892
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3260 - accuracy: 0.8895 - val_loss: 0.3265 - val_accuracy: 0.8925
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3124 - accuracy: 0.8949 - val_loss: 0.3053 - val_accuracy: 0.8970
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3038 - accuracy: 0.8969 - val_loss: 0.3045 - val_accuracy: 0.9021
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2943 - accuracy: 0.8992 - val_loss: 0.3507 - val_accuracy: 0.8803
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2874 - accuracy: 0.9038 - val_loss: 0.3340 - val_accuracy: 0.8925
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2783 - accuracy: 0.9065 - val_loss: 0.3026 - val_accuracy: 0.9000
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2722 - accuracy: 0.9067 - val_loss: 0.2862 - val_accuracy: 0.9027
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2672 - accuracy: 0.9092 - val_loss: 0.3258 - val_accuracy: 0.8956
# Epoch 20/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2600 - accuracy: 0.9129 - val_loss: 0.3217 - val_accuracy: 0.8931
# Epoch 21/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2541 - accuracy: 0.9157 - val_loss: 0.2663 - val_accuracy: 0.9112
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2486 - accuracy: 0.9164 - val_loss: 0.2701 - val_accuracy: 0.9143
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2432 - accuracy: 0.9179 - val_loss: 0.3163 - val_accuracy: 0.8976
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2391 - accuracy: 0.9200 - val_loss: 0.2646 - val_accuracy: 0.9151
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2344 - accuracy: 0.9226 - val_loss: 0.2783 - val_accuracy: 0.9070
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2295 - accuracy: 0.9229 - val_loss: 0.2871 - val_accuracy: 0.9059
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2235 - accuracy: 0.9250 - val_loss: 0.2677 - val_accuracy: 0.9157
# Epoch 28/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2177 - accuracy: 0.9268 - val_loss: 0.2572 - val_accuracy: 0.9176
# Epoch 29/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2146 - accuracy: 0.9289 - val_loss: 0.2915 - val_accuracy: 0.9049
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2093 - accuracy: 0.9312 - val_loss: 0.2682 - val_accuracy: 0.9121
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2074 - accuracy: 0.9319 - val_loss: 0.2874 - val_accuracy: 0.9031
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2055 - accuracy: 0.9324 - val_loss: 0.2701 - val_accuracy: 0.9141
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1990 - accuracy: 0.9327 - val_loss: 0.2897 - val_accuracy: 0.9094

# %%
accuracy_measures_hidden_layers = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Hidden Layers")

# %% [markdown]
# The experiment suggest that 5 layers starts with higher accuracy and was able to complete faster. However, I will start small by selecting three layers for now and optimize it. If the result is still not satisfying then I will consider on adding more layers.

# %% [markdown]
# ### Determining nodes in a layers
# More nodes means more possibility for the model to learn complex relationships. However similar to number of layers, it will results to more training and resources.
#
# On my experiment I started with a low number as recommended with 32 nodes.

# %%
# reset the accuracy measures
accuracy_measures = {}

# The list used to have 16, 128 and 256 nodes. I removed those because of resources and performance reasons.
# The result is little improvement on the model accuracy and I also noticed it just caused an overfitting.
# Hence, I am using a nodes combination below on my experiments

node_list_layer_1 = [32, 64, 128]
node_list_layer_2 = [32, 64, 128]

for nbr_of_nodes_layer_1 in node_list_layer_1:
  for nbr_of_nodes_layer_2 in node_list_layer_2:
    custom_layers = [
      layers.Dense(nbr_of_nodes_layer_1, activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
      layers.Dense(nbr_of_nodes_layer_2, activation=model_config['hidden_activation']),
      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
    ];

    model_name = 'Nodes-' + str(nbr_of_nodes_layer_1) + '-' + str(nbr_of_nodes_layer_2)
    model_config['model_name'] = model_name
    model_config['custom_layers'].clear()
    model_config['custom_layers'].extend(custom_layers)

    history = create_and_run_model(model_config, X_train, y_train_dummy)
    plot_learning_curves(history, model_name)
    accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Nodes-32-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 32)                1664
#
#  dense_51 (Dense)            (None, 32)                1056
#
#  dense_52 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 2885 (11.27 KB)
# Trainable params: 2885 (11.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.0961 - accuracy: 0.5972 - val_loss: 0.8725 - val_accuracy: 0.6787
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8252 - accuracy: 0.6994 - val_loss: 0.7712 - val_accuracy: 0.7132
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.7412 - accuracy: 0.7216 - val_loss: 0.6943 - val_accuracy: 0.7347
# Epoch 4/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.6682 - accuracy: 0.7542 - val_loss: 0.6354 - val_accuracy: 0.7720
# Epoch 5/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.6116 - accuracy: 0.7727 - val_loss: 0.5880 - val_accuracy: 0.7809
# Epoch 6/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.5648 - accuracy: 0.7919 - val_loss: 0.5441 - val_accuracy: 0.8054
# Epoch 7/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5293 - accuracy: 0.8063 - val_loss: 0.5190 - val_accuracy: 0.8227
# Epoch 8/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5008 - accuracy: 0.8181 - val_loss: 0.4994 - val_accuracy: 0.8280
# Epoch 9/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4784 - accuracy: 0.8277 - val_loss: 0.4828 - val_accuracy: 0.8390
# Epoch 10/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4592 - accuracy: 0.8361 - val_loss: 0.4694 - val_accuracy: 0.8422
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4453 - accuracy: 0.8400 - val_loss: 0.4540 - val_accuracy: 0.8424
# Epoch 12/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4313 - accuracy: 0.8452 - val_loss: 0.4437 - val_accuracy: 0.8455
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4201 - accuracy: 0.8502 - val_loss: 0.4292 - val_accuracy: 0.8504
# Epoch 14/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4082 - accuracy: 0.8530 - val_loss: 0.4403 - val_accuracy: 0.8402
# Epoch 15/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3980 - accuracy: 0.8567 - val_loss: 0.4194 - val_accuracy: 0.8459
# Epoch 16/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3887 - accuracy: 0.8606 - val_loss: 0.4120 - val_accuracy: 0.8610
# Epoch 17/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3802 - accuracy: 0.8652 - val_loss: 0.4081 - val_accuracy: 0.8658
# Epoch 18/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3723 - accuracy: 0.8669 - val_loss: 0.3924 - val_accuracy: 0.8628
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3656 - accuracy: 0.8675 - val_loss: 0.4092 - val_accuracy: 0.8585
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3603 - accuracy: 0.8733 - val_loss: 0.3931 - val_accuracy: 0.8658
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3542 - accuracy: 0.8738 - val_loss: 0.3718 - val_accuracy: 0.8764
# Epoch 22/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3471 - accuracy: 0.8758 - val_loss: 0.3722 - val_accuracy: 0.8750
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3414 - accuracy: 0.8769 - val_loss: 0.3702 - val_accuracy: 0.8721
# Epoch 24/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3368 - accuracy: 0.8817 - val_loss: 0.3648 - val_accuracy: 0.8764
# Epoch 25/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3325 - accuracy: 0.8821 - val_loss: 0.3646 - val_accuracy: 0.8740
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3265 - accuracy: 0.8840 - val_loss: 0.3575 - val_accuracy: 0.8805
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3216 - accuracy: 0.8871 - val_loss: 0.3504 - val_accuracy: 0.8793
# Epoch 28/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3175 - accuracy: 0.8871 - val_loss: 0.3468 - val_accuracy: 0.8813
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3148 - accuracy: 0.8900 - val_loss: 0.3775 - val_accuracy: 0.8713
# Epoch 30/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3088 - accuracy: 0.8917 - val_loss: 0.3469 - val_accuracy: 0.8817
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3078 - accuracy: 0.8921 - val_loss: 0.3439 - val_accuracy: 0.8850
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3018 - accuracy: 0.8947 - val_loss: 0.3452 - val_accuracy: 0.8821
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2989 - accuracy: 0.8951 - val_loss: 0.3460 - val_accuracy: 0.8825
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2945 - accuracy: 0.8977 - val_loss: 0.3286 - val_accuracy: 0.8890
# Epoch 35/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2899 - accuracy: 0.9011 - val_loss: 0.3293 - val_accuracy: 0.8909
# Epoch 36/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2868 - accuracy: 0.9014 - val_loss: 0.3234 - val_accuracy: 0.8929
# Epoch 37/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2821 - accuracy: 0.9026 - val_loss: 0.3415 - val_accuracy: 0.8850
# Epoch 38/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2819 - accuracy: 0.9042 - val_loss: 0.3150 - val_accuracy: 0.8943
# Epoch 39/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2779 - accuracy: 0.9042 - val_loss: 0.3245 - val_accuracy: 0.8921
# Epoch 40/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2747 - accuracy: 0.9068 - val_loss: 0.3501 - val_accuracy: 0.8835
# Epoch 41/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2717 - accuracy: 0.9060 - val_loss: 0.3249 - val_accuracy: 0.8921
# Epoch 42/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2691 - accuracy: 0.9092 - val_loss: 0.3132 - val_accuracy: 0.9007
# Epoch 43/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2660 - accuracy: 0.9114 - val_loss: 0.3160 - val_accuracy: 0.8998
# Epoch 44/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.2649 - accuracy: 0.9100 - val_loss: 0.3307 - val_accuracy: 0.8890
# Epoch 45/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2609 - accuracy: 0.9116 - val_loss: 0.3444 - val_accuracy: 0.8860
# Epoch 46/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2604 - accuracy: 0.9118 - val_loss: 0.3023 - val_accuracy: 0.8954
# Epoch 47/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2566 - accuracy: 0.9123 - val_loss: 0.2980 - val_accuracy: 0.9033
# Epoch 48/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2552 - accuracy: 0.9147 - val_loss: 0.3255 - val_accuracy: 0.8913
# Epoch 49/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2534 - accuracy: 0.9153 - val_loss: 0.3161 - val_accuracy: 0.8964
# Epoch 50/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2494 - accuracy: 0.9149 - val_loss: 0.3151 - val_accuracy: 0.9023
# Model: "Nodes-32-64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_53 (Dense)            (None, 32)                1664
#
#  dense_54 (Dense)            (None, 64)                2112
#
#  dense_55 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 4101 (16.02 KB)
# Trainable params: 4101 (16.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 5s 6ms/step - loss: 1.0644 - accuracy: 0.6278 - val_loss: 0.8321 - val_accuracy: 0.6965
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7801 - accuracy: 0.7186 - val_loss: 0.7180 - val_accuracy: 0.7494
# Epoch 3/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.6907 - accuracy: 0.7465 - val_loss: 0.6498 - val_accuracy: 0.7592
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0
50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2750 - accuracy: 0.9062 - val_loss: 0.3142 - val_accuracy: 0.8970
# Epoch 35/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2709 - accuracy: 0.9066 - val_loss: 0.3174 - val_accuracy: 0.8925
# Epoch 36/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2679 - accuracy: 0.9087 - val_loss: 0.2996 - val_accuracy: 0.9035
# Epoch 37/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2642 - accuracy: 0.9099 - val_loss: 0.3534 - val_accuracy: 0.8793
# Epoch 38/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2634 - accuracy: 0.9109 - val_loss: 0.2864 - val_accuracy: 0.9068
# Epoch 39/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2585 - accuracy: 0.9123 - val_loss: 0.2947 - val_accuracy: 0.9068
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2547 - accuracy: 0.9140 - val_loss: 0.3262 - val_accuracy: 0.8907
# Epoch 41/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2526 - accuracy: 0.9150 - val_loss: 0.3124 - val_accuracy: 0.8923
# Epoch 42/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2487 - accuracy: 0.9159 - val_loss: 0.2903 - val_accuracy: 0.9102
# Epoch 43/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2465 - accuracy: 0.9155 - val_loss: 0.2875 - val_accuracy: 0.9047
# Epoch 44/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2435 - accuracy: 0.9175 - val_loss: 0.2825 - val_accuracy: 0.9066
# Epoch 45/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2398 - accuracy: 0.9177 - val_loss: 0.3385 - val_accuracy: 0.8803
# Epoch 46/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2388 - accuracy: 0.9190 - val_loss: 0.2702 - val_accuracy: 0.9074
# Epoch 47/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2358 - accuracy: 0.9202 - val_loss: 0.2766 - val_accuracy: 0.9096
# Model: "Nodes-32-128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 32)                1664
#
#  dense_57 (Dense)            (None, 128)               4224
#
#  dense_58 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 6533 (25.52 KB)
# Trainable params: 6533 (25.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.0614 - accuracy: 0.6160 - val_loss: 0.8273 - val_accuracy: 0.6940
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7701 - accuracy: 0.7216 - val_loss: 0.7013 - val_accuracy: 0.7522
# Epoch 3/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.6641 - accuracy: 0.7557 - val_loss: 0.6216 - val_accuracy: 0.7649
# Epoch 4/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5877 - accuracy: 0.7851 - val_loss: 0.5515 - val_accuracy: 0.7926
# Epoch 5/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7998 - val_loss: 0.5436 - val_accuracy: 0.7938
# Epoch 6/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5016 - accuracy: 0.8168 - val_loss: 0.4860 - val_accuracy: 0.8280
# Epoch 7/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4732 - accuracy: 0.8306 - val_loss: 0.4658 - val_accuracy: 0.8408
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4489 - accuracy: 0.8382 - val_loss: 0.4501 - val_accuracy: 0.8449
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4305 - accuracy: 0.8451 - val_loss: 0.4697 - val_accuracy: 0.8294
# Epoch 10/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4140 - accuracy: 0.8546 - val_loss: 0.4199 - val_accuracy: 0.8658
# Epoch 11/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.4015 - accuracy: 0.8604 - val_loss: 0.4162 - val_accuracy: 0.8483
# Epoch 12/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3884 - accuracy: 0.8644 - val_loss: 0.4010 - val_accuracy: 0.8640
# Epoch 13/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3768 - accuracy: 0.8702 - val_loss: 0.3921 - val_accuracy: 0.8616
# Epoch 14/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3674 - accuracy: 0.8718 - val_loss: 0.3858 - val_accuracy: 0.8721
# Epoch 15/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3560 - accuracy: 0.8777 - val_loss: 0.3843 - val_accuracy: 0.8650
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3478 - accuracy: 0.8830 - val_loss: 0.3798 - val_accuracy: 0.8695
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3391 - accuracy: 0.8827 - val_loss: 0.3823 - val_accuracy: 0.8772
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3318 - accuracy: 0.8856 - val_loss: 0.3539 - val_accuracy: 0.8813
# Epoch 19/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3245 - accuracy: 0.8870 - val_loss: 0.3616 - val_accuracy: 0.8831
# Epoch 20/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.3172 - accuracy: 0.8904 - val_loss: 0.3768 - val_accuracy: 0.8711
# Epoch 21/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3115 - accuracy: 0.8933 - val_loss: 0.3314 - val_accuracy: 0.8907
# Epoch 22/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3043 - accuracy: 0.8967 - val_loss: 0.3166 - val_accuracy: 0.8949
# Epoch 23/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2974 - accuracy: 0.8975 - val_loss: 0.3362 - val_accuracy: 0.8905
# Epoch 24/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2923 - accuracy: 0.8995 - val_loss: 0.3170 - val_accuracy: 0.8937
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2879 - accuracy: 0.9001 - val_loss: 0.3141 - val_accuracy: 0.8956
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2813 - accuracy: 0.9037 - val_loss: 0.3086 - val_accuracy: 0.8978
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2763 - accuracy: 0.9064 - val_loss: 0.3062 - val_accuracy: 0.9004
# Epoch 28/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2725 - accuracy: 0.9069 - val_loss: 0.2975 - val_accuracy: 0.9035
# Epoch 29/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2678 - accuracy: 0.9085 - val_loss: 0.3313 - val_accuracy: 0.8880
# Epoch 30/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2625 - accuracy: 0.9119 - val_loss: 0.3035 - val_accuracy: 0.8992
# Epoch 31/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2609 - accuracy: 0.9120 - val_loss: 0.3039 - val_accuracy: 0.9035
# Epoch 32/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2546 - accuracy: 0.9145 - val_loss: 0.3011 - val_accuracy: 0.9025
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2514 - accuracy: 0.9147 - val_loss: 0.3044 - val_accuracy: 0.9023
# Model: "Nodes-64-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_59 (Dense)            (None, 64)                3328
#
#  dense_60 (Dense)            (None, 32)                2080
#
#  dense_61 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 5573 (21.77 KB)
# Trainable params: 5573 (21.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.0451 - accuracy: 0.6277 - val_loss: 0.8105 - val_accuracy: 0.7087
# Epoch 2/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0
50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2381 - accuracy: 0.9174 - val_loss: 0.2685 - val_accuracy: 0.9112
# Epoch 32/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2334 - accuracy: 0.9180 - val_loss: 0.2736 - val_accuracy: 0.9123
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2302 - accuracy: 0.9203 - val_loss: 0.2841 - val_accuracy: 0.9070
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2277 - accuracy: 0.9197 - val_loss: 0.2807 - val_accuracy: 0.8994
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2224 - accuracy: 0.9232 - val_loss: 0.2587 - val_accuracy: 0.9147
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2195 - accuracy: 0.9259 - val_loss: 0.2502 - val_accuracy: 0.9188
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2168 - accuracy: 0.9249 - val_loss: 0.2597 - val_accuracy: 0.9112
# Epoch 38/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2162 - accuracy: 0.9243 - val_loss: 0.2398 - val_accuracy: 0.9190
# Epoch 39/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2124 - accuracy: 0.9258 - val_loss: 0.2570 - val_accuracy: 0.9167
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2090 - accuracy: 0.9305 - val_loss: 0.2636 - val_accuracy: 0.9131
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2083 - accuracy: 0.9292 - val_loss: 0.2571 - val_accuracy: 0.9149
# Epoch 42/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2037 - accuracy: 0.9292 - val_loss: 0.2646 - val_accuracy: 0.9135
# Epoch 43/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2027 - accuracy: 0.9303 - val_loss: 0.2391 - val_accuracy: 0.9178
# Model: "Nodes-64-64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_62 (Dense)            (None, 64)                3328
#
#  dense_63 (Dense)            (None, 64)                4160
#
#  dense_64 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 7813 (30.52 KB)
# Trainable params: 7813 (30.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.0027 - accuracy: 0.6461 - val_loss: 0.7744 - val_accuracy: 0.7142
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7044 - accuracy: 0.7473 - val_loss: 0.6276 - val_accuracy: 0.7795
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.5829 - accuracy: 0.7867 - val_loss: 0.5388 - val_accuracy: 0.7972
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5044 - accuracy: 0.8155 - val_loss: 0.4730 - val_accuracy: 0.8302
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4606 - accuracy: 0.8374 - val_loss: 0.4646 - val_accuracy: 0.8316
# Epoch 6/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4293 - accuracy: 0.8493 - val_loss: 0.4132 - val_accuracy: 0.8626
# Epoch 7/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4045 - accuracy: 0.8573 - val_loss: 0.3996 - val_accuracy: 0.8644
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3832 - accuracy: 0.8646 - val_loss: 0.3828 - val_accuracy: 0.8744
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3664 - accuracy: 0.8699 - val_loss: 0.4097 - val_accuracy: 0.8571
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3520 - accuracy: 0.8783 - val_loss: 0.3610 - val_accuracy: 0.8823
# Epoch 11/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3410 - accuracy: 0.8819 - val_loss: 0.3619 - val_accuracy: 0.8772
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3300 - accuracy: 0.8859 - val_loss: 0.3322 - val_accuracy: 0.8854
# Epoch 13/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3195 - accuracy: 0.8904 - val_loss: 0.3191 - val_accuracy: 0.8921
# Epoch 14/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3106 - accuracy: 0.8905 - val_loss: 0.3204 - val_accuracy: 0.8976
# Epoch 15/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3022 - accuracy: 0.8949 - val_loss: 0.3321 - val_accuracy: 0.8923
# Epoch 16/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2942 - accuracy: 0.8994 - val_loss: 0.3206 - val_accuracy: 0.8929
# Epoch 17/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2866 - accuracy: 0.9024 - val_loss: 0.3256 - val_accuracy: 0.8964
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2788 - accuracy: 0.9047 - val_loss: 0.2940 - val_accuracy: 0.9043
# Epoch 19/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2743 - accuracy: 0.9051 - val_loss: 0.3462 - val_accuracy: 0.8797
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2678 - accuracy: 0.9073 - val_loss: 0.3020 - val_accuracy: 0.9023
# Epoch 21/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2631 - accuracy: 0.9105 - val_loss: 0.2813 - val_accuracy: 0.9035
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2584 - accuracy: 0.9112 - val_loss: 0.2687 - val_accuracy: 0.9102
# Epoch 23/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2516 - accuracy: 0.9132 - val_loss: 0.2821 - val_accuracy: 0.9064
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2481 - accuracy: 0.9146 - val_loss: 0.2754 - val_accuracy: 0.9127
# Epoch 25/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2440 - accuracy: 0.9162 - val_loss: 0.2666 - val_accuracy: 0.9112
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2392 - accuracy: 0.9192 - val_loss: 0.2595 - val_accuracy: 0.9176
# Epoch 27/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2340 - accuracy: 0.9210 - val_loss: 0.2641 - val_accuracy: 0.9149
# Epoch 28/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2307 - accuracy: 0.9241 - val_loss: 0.2554 - val_accuracy: 0.9175
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2275 - accuracy: 0.9231 - val_loss: 0.2824 - val_accuracy: 0.9096
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2215 - accuracy: 0.9267 - val_loss: 0.2699 - val_accuracy: 0.9096
# Epoch 31/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2201 - accuracy: 0.9274 - val_loss: 0.2725 - val_accuracy: 0.9141
# Model: "Nodes-64-128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_65 (Dense)            (None, 64)                3328
#
#  dense_66 (Dense)            (None, 128)               8320
#
#  dense_67 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 12293 (48.02 KB)
# Trainable params: 12293 (48.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9802 - accuracy: 0.6517 - val_loss: 0.7650 - val_accuracy: 0.7243
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6919 - accuracy: 0.7513 - val_loss: 0.6127 - val_accuracy: 0.7814
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.5723 - accuracy: 0.7893 - val_loss: 0.5358 - val_accuracy: 0.8035
# Epoch 4/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4999 - accuracy: 0.8173 - val_loss: 0.4701 - val_accuracy: 0.8276
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4596 - accuracy: 0.8341 - val_loss: 0.4748 - val_accuracy: 0.8182
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4286 - accuracy: 0.8458 - val_loss: 0.4231 - val_accuracy: 0.8575
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4028 - accuracy: 0.8570 - val_loss: 0.3942 - val_accuracy: 0.8579
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3797 - accuracy: 0.8641 - val_loss: 0.3729 - val_accuracy: 0.8701
# Epoch 9/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3608 - accuracy: 0.8720 - val_loss: 0.4072 - val_accuracy: 0.8607
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3430 - accuracy: 0.8796 - val_loss: 0.3591 - val_accuracy: 0.8722
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3296 - accuracy: 0.8840 - val_loss: 0.3619 - val_accuracy: 0.8742
# Epoch 12/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3165 - accuracy: 0.8889 - val_loss: 0.3177 - val_accuracy: 0.8911
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3035 - accuracy: 0.8941 - val_loss: 0.3075 - val_accuracy: 0.8960
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2942 - accuracy: 0.8979 - val_loss: 0.3082 - val_accuracy: 0.8964
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2840 - accuracy: 0.9015 - val_loss: 0.3157 - val_accuracy: 0.8888
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2744 - accuracy: 0.9061 - val_loss: 0.2988 - val_accuracy: 0.8972
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2671 - accuracy: 0.9080 - val_loss: 0.3098 - val_accuracy: 0.8968
# Epoch 18/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2594 - accuracy: 0.9094 - val_loss: 0.2755 - val_accuracy: 0.9108
# Epoch 19/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2539 - accuracy: 0.9130 - val_loss: 0.3409 - val_accuracy: 0.8821
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2462 - accuracy: 0.9179 - val_loss: 0.2955 - val_accuracy: 0.9009
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2419 - accuracy: 0.9193 - val_loss: 0.2574 - val_accuracy: 0.9118
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2356 - accuracy: 0.9199 - val_loss: 0.2510 - val_accuracy: 0.9171
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2293 - accuracy: 0.9231 - val_loss: 0.2611 - val_accuracy: 0.9123
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2242 - accuracy: 0.9257 - val_loss: 0.2597 - val_accuracy: 0.9190
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2211 - accuracy: 0.9249 - val_loss: 0.2459 - val_accuracy: 0.9169
# Epoch 26/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2162 - accuracy: 0.9283 - val_loss: 0.2448 - val_accuracy: 0.9222
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2117 - accuracy: 0.9300 - val_loss: 0.2459 - val_accuracy: 0.9206
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2077 - accuracy: 0.9308 - val_loss: 0.2388 - val_accuracy: 0.9241
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2040 - accuracy: 0.9329 - val_loss: 0.2809 - val_accuracy: 0.9045
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1992 - accuracy: 0.9339 - val_loss: 0.2475 - val_accuracy: 0.9163
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1979 - accuracy: 0.9346 - val_loss: 0.2290 - val_accuracy: 0.9277
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1945 - accuracy: 0.9348 - val_loss: 0.2378 - val_accuracy: 0.9224
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1901 - accuracy: 0.9363 - val_loss: 0.2417 - val_accuracy: 0.9275
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1868 - accuracy: 0.9382 - val_loss: 0.2371 - val_accuracy: 0.9241
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1823 - accuracy: 0.9398 - val_loss: 0.2497 - val_accuracy: 0.9159
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1810 - accuracy: 0.9400 - val_loss: 0.2124 - val_accuracy: 0.9351
# Epoch 37/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1766 - accuracy: 0.9397 - val_loss: 0.2237 - val_accuracy: 0.9330
# Epoch 38/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1752 - accuracy: 0.9413 - val_loss: 0.2137 - val_accuracy: 0.9344
# Epoch 39/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1719 - accuracy: 0.9424 - val_loss: 0.2195 - val_accuracy: 0.9275
# Epoch 40/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1682 - accuracy: 0.9454 - val_loss: 0.2275 - val_accuracy: 0.9306
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1670 - accuracy: 0.9440 - val_loss: 0.2131 - val_accuracy: 0.9351
# Model: "Nodes-128-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_68 (Dense)            (None, 128)               6656
#
#  dense_69 (Dense)            (None, 32)                4128
#
#  dense_70 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 10949 (42.77 KB)
# Trainable params: 10949 (42.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0
50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2132 - accuracy: 0.9281 - val_loss: 0.2715 - val_accuracy: 0.9106
# Model: "Nodes-128-64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_71 (Dense)            (None, 128)               6656
#
#  dense_72 (Dense)            (None, 64)                8256
#
#  dense_73 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 0.9615 - accuracy: 0.6553 - val_loss: 0.7516 - val_accuracy: 0.7215
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6953 - accuracy: 0.7473 - val_loss: 0.6205 - val_accuracy: 0.7722
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5806 - accuracy: 0.7838 - val_loss: 0.5378 - val_accuracy: 0.8039
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4995 - accuracy: 0.8175 - val_loss: 0.4675 - val_accuracy: 0.8278
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4485 - accuracy: 0.8377 - val_loss: 0.4387 - val_accuracy: 0.8373
# Epoch 6/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4114 - accuracy: 0.8522 - val_loss: 0.3923 - val_accuracy: 0.8610
# Epoch 7/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3834 - accuracy: 0.8627 - val_loss: 0.3774 - val_accuracy: 0.8732
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3601 - accuracy: 0.8724 - val_loss: 0.3681 - val_accuracy: 0.8776
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3432 - accuracy: 0.8765 - val_loss: 0.4106 - val_accuracy: 0.8534
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3267 - accuracy: 0.8847 - val_loss: 0.3424 - val_accuracy: 0.8874
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3144 - accuracy: 0.8882 - val_loss: 0.3515 - val_accuracy: 0.8789
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3026 - accuracy: 0.8926 - val_loss: 0.3078 - val_accuracy: 0.8960
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2903 - accuracy: 0.8995 - val_loss: 0.3091 - val_accuracy: 0.8982
# Epoch 14/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2808 - accuracy: 0.9008 - val_loss: 0.3063 - val_accuracy: 0.9004
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2718 - accuracy: 0.9062 - val_loss: 0.3122 - val_accuracy: 0.8939
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2619 - accuracy: 0.9102 - val_loss: 0.3067 - val_accuracy: 0.8950
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2552 - accuracy: 0.9115 - val_loss: 0.3056 - val_accuracy: 0.9051
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2466 - accuracy: 0.9144 - val_loss: 0.2902 - val_accuracy: 0.9039
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2425 - accuracy: 0.9152 - val_loss: 0.2935 - val_accuracy: 0.9037
# Epoch 20/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2335 - accuracy: 0.9203 - val_loss: 0.2879 - val_accuracy: 0.9043
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2295 - accuracy: 0.9205 - val_loss: 0.2593 - val_accuracy: 0.9153
# Epoch 22/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2247 - accuracy: 0.9225 - val_loss: 0.2489 - val_accuracy: 0.9228
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2164 - accuracy: 0.9272 - val_loss: 0.2590 - val_accuracy: 0.9141
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2137 - accuracy: 0.9268 - val_loss: 0.2425 - val_accuracy: 0.9184
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2094 - accuracy: 0.9282 - val_loss: 0.2469 - val_accuracy: 0.9190
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2049 - accuracy: 0.9310 - val_loss: 0.2518 - val_accuracy: 0.9192
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1998 - accuracy: 0.9319 - val_loss: 0.2520 - val_accuracy: 0.9167
# Model: "Nodes-128-128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_74 (Dense)            (None, 128)               6656
#
#  dense_75 (Dense)            (None, 128)               16512
#
#  dense_76 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 23813 (93.02 KB)
# Trainable params: 23813 (93.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9173 - accuracy: 0.6709 - val_loss: 0.7116 - val_accuracy: 0.7380
# Epoch 2/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.6431 - accuracy: 0.7679 - val_loss: 0.5630 - val_accuracy: 0.7907
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.5262 - accuracy: 0.8084 - val_loss: 0.4833 - val_accuracy: 0.8310
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4543 - accuracy: 0.8371 - val_loss: 0.4218 - val_accuracy: 0.8459
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4125 - accuracy: 0.8539 - val_loss: 0.4129 - val_accuracy: 0.8548
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3824 - accuracy: 0.8638 - val_loss: 0.3625 - val_accuracy: 0.8742
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3566 - accuracy: 0.8744 - val_loss: 0.3479 - val_accuracy: 0.8801
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3346 - accuracy: 0.8822 - val_loss: 0.3475 - val_accuracy: 0.8831
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3174 - accuracy: 0.8884 - val_loss: 0.3788 - val_accuracy: 0.8689
# Epoch 10/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3017 - accuracy: 0.8946 - val_loss: 0.3346 - val_accuracy: 0.8866
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2883 - accuracy: 0.8991 - val_loss: 0.3038 - val_accuracy: 0.8899
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2772 - accuracy: 0.9010 - val_loss: 0.2736 - val_accuracy: 0.9072
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2646 - accuracy: 0.9079 - val_loss: 0.2750 - val_accuracy: 0.9096
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2549 - accuracy: 0.9096 - val_loss: 0.2708 - val_accuracy: 0.9119
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2449 - accuracy: 0.9145 - val_loss: 0.2892 - val_accuracy: 0.9055
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2359 - accuracy: 0.9184 - val_loss: 0.2538 - val_accuracy: 0.9141
# Epoch 17/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2282 - accuracy: 0.9220 - val_loss: 0.2742 - val_accuracy: 0.9121
# Epoch 18/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2202 - accuracy: 0.9237 - val_loss: 0.2480 - val_accuracy: 0.9200
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2139 - accuracy: 0.9254 - val_loss: 0.3215 - val_accuracy: 0.8943
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2072 - accuracy: 0.9301 - val_loss: 0.2814 - val_accuracy: 0.9013
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2018 - accuracy: 0.9303 - val_loss: 0.2244 - val_accuracy: 0.9251
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1975 - accuracy: 0.9324 - val_loss: 0.2212 - val_accuracy: 0.9294
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1902 - accuracy: 0.9356 - val_loss: 0.2421 - val_accuracy: 0.9167
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1854 - accuracy: 0.9361 - val_loss: 0.2119 - val_accuracy: 0.9310
# Epoch 25/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1812 - accuracy: 0.9370 - val_loss: 0.2191 - val_accuracy: 0.9277
# Epoch 26/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.1787 - accuracy: 0.9393 - val_loss: 0.2179 - val_accuracy: 0.9336
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1721 - accuracy: 0.9414 - val_loss: 0.2161 - val_accuracy: 0.9263
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1700 - accuracy: 0.9419 - val_loss: 0.2037 - val_accuracy: 0.9353
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1655 - accuracy: 0.9447 - val_loss: 0.2299 - val_accuracy: 0.9271
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1602 - accuracy: 0.9447 - val_loss: 0.2219 - val_accuracy: 0.9230
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1599 - accuracy: 0.9457 - val_loss: 0.1975 - val_accuracy: 0.9365
# Epoch 32/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1552 - accuracy: 0.9463 - val_loss: 0.2225 - val_accuracy: 0.9261
# Epoch 33/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1511 - accuracy: 0.9498 - val_loss: 0.1906 - val_accuracy: 0.9399
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1507 - accuracy: 0.9490 - val_loss: 0.2279 - val_accuracy: 0.9247
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1457 - accuracy: 0.9516 - val_loss: 0.1958 - val_accuracy: 0.9357
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1430 - accuracy: 0.9517 - val_loss: 0.1784 - val_accuracy: 0.9469
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1400 - accuracy: 0.9520 - val_loss: 0.1953 - val_accuracy: 0.9375
# Epoch 38/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1385 - accuracy: 0.9542 - val_loss: 0.1938 - val_accuracy: 0.9379
# Epoch 39/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.1336 - accuracy: 0.9529 - val_loss: 0.2048 - val_accuracy: 0.9359
# Epoch 40/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1328 - accuracy: 0.9564 - val_loss: 0.1731 - val_accuracy: 0.9465
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1315 - accuracy: 0.9545 - val_loss: 0.1936 - val_accuracy: 0.9377

# %%
accuracy_measures_nodes = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Nodes in a Layer")

# %% [markdown]
# The nodes 128 and 64 was faster to complete compared to other combination of nodes and it also offer a good accuracy. The model 128 nodes for both layers have a higher accuracy but it can lead to overfitting. I will use two layers with 128 and 64 nodes assigned respectively.

# %% [markdown]
# ### Choosing Activation Function
#
# There are number of algorithms available for activation functions. In general, rectified linear unit works best for regular  artificial neural network (ANN) and convolutional network (CNN). Sigmoid works best for RNNs.

# %%
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64

activation_list = ['relu','sigmoid','tanh']

for activation in activation_list:

  model_config['hidden_activation'] = activation

  custom_layers = [
    layers.Dense(128, activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
    layers.Dense(64, activation=model_config['hidden_activation']),
    layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];

  model_name = 'Model-' + activation
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Model-relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_77 (Dense)            (None, 128)               6656
#
#  dense_78 (Dense)            (None, 64)                8256
#
#  dense_79 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9657 - accuracy: 0.6537 - val_loss: 0.7481 - val_accuracy: 0.7233
# Epoch 2/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.6822 - accuracy: 0.7506 - val_loss: 0.6025 - val_accuracy: 0.7791
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5619 - accuracy: 0.7892 - val_loss: 0.5166 - val_accuracy: 0.8151
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4836 - accuracy: 0.8255 - val_loss: 0.4422 - val_accuracy: 0.8443
# Epoch 5/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4406 - accuracy: 0.8424 - val_loss: 0.4392 - val_accuracy: 0.8408
# Epoch 6/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4108 - accuracy: 0.8536 - val_loss: 0.3876 - val_accuracy: 0.8634
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3850 - accuracy: 0.8645 - val_loss: 0.3743 - val_accuracy: 0.8699
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3628 - accuracy: 0.8737 - val_loss: 0.3637 - val_accuracy: 0.8768
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3466 - accuracy: 0.8753 - val_loss: 0.4079 - val_accuracy: 0.8591
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3305 - accuracy: 0.8861 - val_loss: 0.3422 - val_accuracy: 0.8886
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3177 - accuracy: 0.8891 - val_loss: 0.3182 - val_accuracy: 0.8939
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3058 - accuracy: 0.8925 - val_loss: 0.3021 - val_accuracy: 0.8986
# Epoch 13/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2935 - accuracy: 0.8967 - val_loss: 0.2885 - val_accuracy: 0.8998
# Epoch 14/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2832 - accuracy: 0.9012 - val_loss: 0.2948 - val_accuracy: 0.9031
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2744 - accuracy: 0.9050 - val_loss: 0.3030 - val_accuracy: 0.8917
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2645 - accuracy: 0.9096 - val_loss: 0.3074 - val_accuracy: 0.8937
# Epoch 17/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2571 - accuracy: 0.9099 - val_loss: 0.2897 - val_accuracy: 0.9066
# Epoch 18/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2490 - accuracy: 0.9127 - val_loss: 0.2706 - val_accuracy: 0.9100
# Epoch 19/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2452 - accuracy: 0.9154 - val_loss: 0.3251 - val_accuracy: 0.8935
# Epoch 20/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2356 - accuracy: 0.9190 - val_loss: 0.2691 - val_accuracy: 0.9035
# Epoch 21/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2322 - accuracy: 0.9205 - val_loss: 0.2468 - val_accuracy: 0.9149
# Epoch 22/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2269 - accuracy: 0.9220 - val_loss: 0.2289 - val_accuracy: 0.9277
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2199 - accuracy: 0.9256 - val_loss: 0.2489 - val_accuracy: 0.9161
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2154 - accuracy: 0.9274 - val_loss: 0.2322 - val_accuracy: 0.9255
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2108 - accuracy: 0.9281 - val_loss: 0.2335 - val_accuracy: 0.9196
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2059 - accuracy: 0.9305 - val_loss: 0.2194 - val_accuracy: 0.9296
# Epoch 27/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1995 - accuracy: 0.9309 - val_loss: 0.2293 - val_accuracy: 0.9214
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1958 - accuracy: 0.9328 - val_loss: 0.2123 - val_accuracy: 0.9334
# Epoch 29/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1938 - accuracy: 0.9343 - val_loss: 0.2470 - val_accuracy: 0.9192
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1869 - accuracy: 0.9375 - val_loss: 0.2474 - val_accuracy: 0.9116
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1859 - accuracy: 0.9398 - val_loss: 0.2392 - val_accuracy: 0.9222
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1816 - accuracy: 0.9383 - val_loss: 0.2280 - val_accuracy: 0.9255
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1781 - accuracy: 0.9396 - val_loss: 0.2290 - val_accuracy: 0.9279
# Model: "Model-sigmoid"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 128)               6656
#
#  dense_81 (Dense)            (None, 64)                8256
#
#  dense_82 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.4333 - accuracy: 0.4157 - val_loss: 1.2115 - val_accuracy: 0.5517
# Epoch 2/50
# 636/636 [==============================] - 2s 4ms/step - loss: 1.0942 - accuracy: 0.6076 - val_loss: 0.9777 - val_accuracy: 0.6568
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.9454 - accuracy: 0.6596 - val_loss: 0.8948 - val_accuracy: 0.6710
# Epoch 4/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.8804 - accuracy: 0.6836 - val_loss: 0.8446 - val_accuracy: 0.6865
# Epoch 5/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.8398 - accuracy: 0.6958 - val_loss: 0.8068 - val_accuracy: 0.6981
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8077 - accuracy: 0.7110 - val_loss: 0.7812 - val_accuracy: 0.7115
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7819 - accuracy: 0.7160 - val_loss: 0.7507 - val_accuracy: 0.7231
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7584 - accuracy: 0.7254 - val_loss: 0.7489 - val_accuracy: 0.7321
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7390 - accuracy: 0.7279 - val_loss: 0.7400 - val_accuracy: 0.7311
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7229 - accuracy: 0.7358 - val_loss: 0.7208 - val_accuracy: 0.7366
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7096 - accuracy: 0.7392 - val_loss: 0.6883 - val_accuracy: 0.7425
# Epoch 12/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6951 - accuracy: 0.7441 - val_loss: 0.6874 - val_accuracy: 0.7563
# Epoch 13/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.6837 - accuracy: 0.7480 - val_loss: 0.6749 - val_accuracy: 0.7522
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6726 - accuracy: 0.7534 - val_loss: 0.6609 - val_accuracy: 0.7608
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6626 - accuracy: 0.7540 - val_loss: 0.6509 - val_accuracy: 0.7586
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6528 - accuracy: 0.7598 - val_loss: 0.6498 - val_accuracy: 0.7663
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6438 - accuracy: 0.7621 - val_loss: 0.6448 - val_accuracy: 0.7675
# Epoch 18/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.6362 - accuracy: 0.7666 - val_loss: 0.6331 - val_accuracy: 0.7728
# Epoch 19/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.6266 - accuracy: 0.7713 - val_loss: 0.6151 - val_accuracy: 0.7816
# Epoch 20/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6207 - accuracy: 0.7750 - val_loss: 0.6184 - val_accuracy: 0.7787
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6132 - accuracy: 0.7763 - val_loss: 0.6151 - val_accuracy: 0.7885
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6053 - accuracy: 0.7787 - val_loss: 0.6285 - val_accuracy: 0.7789
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5983 - accuracy: 0.7813 - val_loss: 0.6093 - val_accuracy: 0.7897
# Epoch 24/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5910 - accuracy: 0.7870 - val_loss: 0.5829 - val_accuracy: 0.7983
# Epoch 25/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5841 - accuracy: 0.7897 - val_loss: 0.5805 - val_accuracy: 0.8037
# Epoch 26/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5781 - accuracy: 0.7922 - val_loss: 0.5815 - val_accuracy: 0.7930
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5720 - accuracy: 0.7955 - val_loss: 0.5713 - val_accuracy: 0.7928
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5654 - accuracy: 0.7967 - val_loss: 0.5762 - val_accuracy: 0.7905
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7997 - val_loss: 0.5788 - val_accuracy: 0.7966
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5537 - accuracy: 0.8003 - val_loss: 0.5566 - val_accuracy: 0.7940
# Model: "Model-tanh"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_83 (Dense)            (None, 128)               6656
#
#  dense_84 (Dense)            (None, 64)                8256
#
#  dense_85 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9067 - accuracy: 0.6717 - val_loss: 0.7550 - val_accuracy: 0.7180
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7285 - accuracy: 0.7335 - val_loss: 0.6900 - val_accuracy: 0.7518
# Epoch 3/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6747 - accuracy: 0.7500 - val_loss: 0.6451 - val_accuracy: 0.7744
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6291 - accuracy: 0.7700 - val_loss: 0.6018 - val_accuracy: 0.7818
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5943 - accuracy: 0.7831 - val_loss: 0.5759 - val_accuracy: 0.7899
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5606 - accuracy: 0.7963 - val_loss: 0.5331 - val_accuracy: 0.8174
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.8081 - val_loss: 0.5144 - val_accuracy: 0.8170
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5027 - accuracy: 0.8199 - val_loss: 0.4841 - val_accuracy: 0.8308
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4766 - accuracy: 0.8291 - val_loss: 0.4950 - val_accuracy: 0.8280
# Epoch 10/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4533 - accuracy: 0.8373 - val_loss: 0.4424 - val_accuracy: 0.8536
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4327 - accuracy: 0.8463 - val_loss: 0.4233 - val_accuracy: 0.8538
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4123 - accuracy: 0.8544 - val_loss: 0.4161 - val_accuracy: 0.8593
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3942 - accuracy: 0.8618 - val_loss: 0.3873 - val_accuracy: 0.8736
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3780 - accuracy: 0.8675 - val_loss: 0.3735 - val_accuracy: 0.8776
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3615 - accuracy: 0.8759 - val_loss: 0.3851 - val_accuracy: 0.8654
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3455 - accuracy: 0.8811 - val_loss: 0.3574 - val_accuracy: 0.8778
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3332 - accuracy: 0.8846 - val_loss: 0.3422 - val_accuracy: 0.8892
# Epoch 18/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3196 - accuracy: 0.8912 - val_loss: 0.3354 - val_accuracy: 0.8833
# Epoch 19/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3085 - accuracy: 0.8950 - val_loss: 0.3301 - val_accuracy: 0.8897
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2972 - accuracy: 0.8991 - val_loss: 0.3207 - val_accuracy: 0.8935
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2882 - accuracy: 0.9022 - val_loss: 0.2975 - val_accuracy: 0.9009
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2792 - accuracy: 0.9066 - val_loss: 0.2869 - val_accuracy: 0.9066
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2690 - accuracy: 0.9095 - val_loss: 0.2846 - val_accuracy: 0.9082
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2618 - accuracy: 0.9118 - val_loss: 0.2726 - val_accuracy: 0.9127
# Epoch 25/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2532 - accuracy: 0.9141 - val_loss: 0.2835 - val_accuracy: 0.9047
# Epoch 26/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2467 - accuracy: 0.9182 - val_loss: 0.2722 - val_accuracy: 0.9155
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2390 - accuracy: 0.9200 - val_loss: 0.2629 - val_accuracy: 0.9147
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2340 - accuracy: 0.9222 - val_loss: 0.2516 - val_accuracy: 0.9218
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2279 - accuracy: 0.9242 - val_loss: 0.2713 - val_accuracy: 0.9129
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2223 - accuracy: 0.9258 - val_loss: 0.2603 - val_accuracy: 0.9094
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2184 - accuracy: 0.9287 - val_loss: 0.2428 - val_accuracy: 0.9232
# Epoch 32/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2129 - accuracy: 0.9301 - val_loss: 0.2638 - val_accuracy: 0.9104
# Epoch 33/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2089 - accuracy: 0.9326 - val_loss: 0.2520 - val_accuracy: 0.9226
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2035 - accuracy: 0.9331 - val_loss: 0.2612 - val_accuracy: 0.9163
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1981 - accuracy: 0.9363 - val_loss: 0.2404 - val_accuracy: 0.9251
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1940 - accuracy: 0.9356 - val_loss: 0.2234 - val_accuracy: 0.9304
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1910 - accuracy: 0.9368 - val_loss: 0.2532 - val_accuracy: 0.9239
# Epoch 38/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1875 - accuracy: 0.9389 - val_loss: 0.2226 - val_accuracy: 0.9310
# Epoch 39/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1826 - accuracy: 0.9387 - val_loss: 0.2279 - val_accuracy: 0.9271
# Epoch 40/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1799 - accuracy: 0.9433 - val_loss: 0.2397 - val_accuracy: 0.9226
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1778 - accuracy: 0.9398 - val_loss: 0.2148 - val_accuracy: 0.9353
# Epoch 42/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1721 - accuracy: 0.9434 - val_loss: 0.2234 - val_accuracy: 0.9314
# Epoch 43/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1706 - accuracy: 0.9445 - val_loss: 0.2139 - val_accuracy: 0.9320
# Epoch 44/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1673 - accuracy: 0.9458 - val_loss: 0.2187 - val_accuracy: 0.9314
# Epoch 45/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1639 - accuracy: 0.9459 - val_loss: 0.2244 - val_accuracy: 0.9294
# Epoch 46/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1615 - accuracy: 0.9467 - val_loss: 0.2234 - val_accuracy: 0.9261

# %%
accuracy_activation = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Activiation Functions")

# %% [markdown]
# The activation function relu have higher accuracy and completed faster.

# %%
model_config['hidden_activation'] = 'relu'

# %% [markdown]
# ### Initialize Weights
# The initial values of weights play a huge role in the speed of learning and finaly accuracy. Multiple initialization techniques exist.
#
# Random normal works best for most cases but we will run an experiment if that is still the case on our dataset.

# %%
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64
model_config['hidden_activation'] = 'relu'

initializer_list = ['random_normal','zeros','ones',"random_uniform"]

for initializer in initializer_list:

  model_config['weights_initializer'] = initializer

  custom_layers = [
    layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
    layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
    layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];

  model_name = 'Model-' + initializer
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Model-random_normal"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               6656
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 4s 5ms/step - loss: 0.9757 - accuracy: 0.6470 - val_loss: 0.7619 - val_accuracy: 0.7164
# Epoch 2/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.7026 - accuracy: 0.7430 - val_loss: 0.6305 - val_accuracy: 0.7730
# Epoch 3/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5942 - accuracy: 0.7791 - val_loss: 0.5533 - val_accuracy: 0.7976
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5178 - accuracy: 0.8091 - val_loss: 0.4761 - val_accuracy: 0.8213
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4709 - accuracy: 0.8297 - val_loss: 0.4652 - val_accuracy: 0.8239
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4356 - accuracy: 0.8416 - val_loss: 0.4125 - val_accuracy: 0.8563
# Epoch 7/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4088 - accuracy: 0.8539 - val_loss: 0.3947 - val_accuracy: 0.8640
# Epoch 8/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3850 - accuracy: 0.8625 - val_loss: 0.3780 - val_accuracy: 0.8748
# Epoch 9/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3669 - accuracy: 0.8693 - val_loss: 0.4300 - val_accuracy: 0.8451
# Epoch 10/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3498 - accuracy: 0.8773 - val_loss: 0.3570 - val_accuracy: 0.8848
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3358 - accuracy: 0.8817 - val_loss: 0.3565 - val_accuracy: 0.8744
# Epoch 12/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.3228 - accuracy: 0.8853 - val_loss: 0.3254 - val_accuracy: 0.8913
# Epoch 13/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3105 - accuracy: 0.8910 - val_loss: 0.3171 - val_accuracy: 0.8921
# Epoch 14/50
# 636/636 [==============================] - 6s 10ms/step - loss: 0.2999 - accuracy: 0.8958 - val_loss: 0.3098 - val_accuracy: 0.8970
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2893 - accuracy: 0.8994 - val_loss: 0.3094 - val_accuracy: 0.8980
# Epoch 16/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2787 - accuracy: 0.9033 - val_loss: 0.3181 - val_accuracy: 0.8880
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2698 - accuracy: 0.9042 - val_loss: 0.3178 - val_accuracy: 0.8952
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2614 - accuracy: 0.9059 - val_loss: 0.3043 - val_accuracy: 0.8990
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2551 - accuracy: 0.9107 - val_loss: 0.3405 - val_accuracy: 0.8854
# Epoch 20/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2465 - accuracy: 0.9144 - val_loss: 0.3052 - val_accuracy: 0.8929
# Epoch 21/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2406 - accuracy: 0.9176 - val_loss: 0.2725 - val_accuracy: 0.9084
# Epoch 22/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2332 - accuracy: 0.9177 - val_loss: 0.2522 - val_accuracy: 0.9123
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2271 - accuracy: 0.9227 - val_loss: 0.2691 - val_accuracy: 0.9078
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2219 - accuracy: 0.9241 - val_loss: 0.2530 - val_accuracy: 0.9169
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2169 - accuracy: 0.9267 - val_loss: 0.2433 - val_accuracy: 0.9153
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2131 - accuracy: 0.9254 - val_loss: 0.2458 - val_accuracy: 0.9212
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2055 - accuracy: 0.9297 - val_loss: 0.2431 - val_accuracy: 0.9163
# Epoch 28/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2029 - accuracy: 0.9312 - val_loss: 0.2354 - val_accuracy: 0.9222
# Epoch 29/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1987 - accuracy: 0.9327 - val_loss: 0.3089 - val_accuracy: 0.8972
# Epoch 30/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1932 - accuracy: 0.9346 - val_loss: 0.2472 - val_accuracy: 0.9145
# Epoch 31/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1926 - accuracy: 0.9345 - val_loss: 0.2274 - val_accuracy: 0.9255
# Epoch 32/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1881 - accuracy: 0.9360 - val_loss: 0.2452 - val_accuracy: 0.9202
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1849 - accuracy: 0.9375 - val_loss: 0.2193 - val_accuracy: 0.9304
# Epoch 34/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1804 - accuracy: 0.9391 - val_loss: 0.2536 - val_accuracy: 0.9145
# Epoch 35/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1758 - accuracy: 0.9413 - val_loss: 0.2563 - val_accuracy: 0.9143
# Epoch 36/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.1744 - accuracy: 0.9398 - val_loss: 0.2107 - val_accuracy: 0.9320
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1714 - accuracy: 0.9418 - val_loss: 0.2283 - val_accuracy: 0.9275
# Epoch 38/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1693 - accuracy: 0.9418 - val_loss: 0.2086 - val_accuracy: 0.9308
# Epoch 39/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1658 - accuracy: 0.9447 - val_loss: 0.2218 - val_accuracy: 0.9257
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1636 - accuracy: 0.9460 - val_loss: 0.2842 - val_accuracy: 0.9102
# Epoch 41/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1614 - accuracy: 0.9438 - val_loss: 0.2295 - val_accuracy: 0.9249
# Model: "Model-zeros"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               6656
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 1.6078 - accuracy: 0.2144 - val_loss: 1.6059 - val_accuracy: 0.2140
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6072 - accuracy: 0.2164 - val_loss: 1.6058 - val_accuracy: 0.2140
# Epoch 3/50
# 636/636 [==============================] - 3s 5ms/step - loss: 1.6072 - accuracy: 0.2155 - val_loss: 1.6059 - val_accuracy: 0.2140
# Epoch 4/50
# 636/636 [==============================] - 3s 5ms/step - loss: 1.6072 - accuracy: 0.2155 - val_loss: 1.6058 - val_accuracy: 0.2140
# Epoch 5/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.6072 - accuracy: 0.2164 - val_loss: 1.6057 - val_accuracy: 0.2140
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6072 - accuracy: 0.2163 - val_loss: 1.6058 - val_accuracy: 0.2140
# Model: "Model-ones"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               6656
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 66.0626 - accuracy: 0.2025 - val_loss: 29.4420 - val_accuracy: 0.1710
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 7.8911 - accuracy: 0.2258 - val_loss: 1.6043 - val_accuracy: 0.2203
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6084 - accuracy: 0.2128 - val_loss: 1.6043 - val_accuracy: 0.2154
# Epoch 4/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.6053 - accuracy: 0.2145 - val_loss: 1.6039 - val_accuracy: 0.2154
# Epoch 5/50
# 636/636 [==============================] - 3s 5ms/step - loss: 1.6053 - accuracy: 0.2172 - val_loss: 1.6034 - val_accuracy: 0.2154
# Epoch 6/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.6047 - accuracy: 0.2171 - val_loss: 1.6036 - val_accuracy: 0.2154
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6051 - accuracy: 0.2164 - val_loss: 1.6034 - val_accuracy: 0.2154
# Model: "Model-random_uniform"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 128)               6656
#
#  dense_19 (Dense)            (None, 64)                8256
#
#  dense_20 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 1.0112 - accuracy: 0.6299 - val_loss: 0.7962 - val_accuracy: 0.7038
# Epoch 2/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.7492 - accuracy: 0.7221 - val_loss: 0.6786 - val_accuracy: 0.7504
# Epoch 3/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.6414 - accuracy: 0.7625 - val_loss: 0.5883 - val_accuracy: 0.7844
# Epoch 4/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5545 - accuracy: 0.7958 - val_loss: 0.5125 - val_accuracy: 0.8062
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4995 - accuracy: 0.8160 - val_loss: 0.4971 - val_accuracy: 0.8149
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4598 - accuracy: 0.8314 - val_loss: 0.4401 - val_accuracy: 0.8465
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4293 - accuracy: 0.8437 - val_loss: 0.4224 - val_accuracy: 0.8540
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4039 - accuracy: 0.8550 - val_loss: 0.3947 - val_accuracy: 0.8634
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3845 - accuracy: 0.8593 - val_loss: 0.4245 - val_accuracy: 0.8498
# Epoch 10/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3658 - accuracy: 0.8695 - val_loss: 0.3758 - val_accuracy: 0.8740
# Epoch 11/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3519 - accuracy: 0.8753 - val_loss: 0.3652 - val_accuracy: 0.8719
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3374 - accuracy: 0.8785 - val_loss: 0.3394 - val_accuracy: 0.8831
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3236 - accuracy: 0.8849 - val_loss: 0.3289 - val_accuracy: 0.8886
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3134 - accuracy: 0.8874 - val_loss: 0.3263 - val_accuracy: 0.8929
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3032 - accuracy: 0.8911 - val_loss: 0.3378 - val_accuracy: 0.8888
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2927 - accuracy: 0.8975 - val_loss: 0.3293 - val_accuracy: 0.8917
# Epoch 17/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2821 - accuracy: 0.8994 - val_loss: 0.3322 - val_accuracy: 0.8838
# Epoch 18/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2735 - accuracy: 0.9032 - val_loss: 0.3104 - val_accuracy: 0.8964
# Epoch 19/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2668 - accuracy: 0.9057 - val_loss: 0.3149 - val_accuracy: 0.8927
# Epoch 20/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2577 - accuracy: 0.9101 - val_loss: 0.3276 - val_accuracy: 0.8895
# Epoch 21/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2518 - accuracy: 0.9120 - val_loss: 0.2738 - val_accuracy: 0.9029
# Epoch 22/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2441 - accuracy: 0.9146 - val_loss: 0.2610 - val_accuracy: 0.9110
# Epoch 23/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2366 - accuracy: 0.9188 - val_loss: 0.2670 - val_accuracy: 0.9114
# Epoch 24/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2322 - accuracy: 0.9203 - val_loss: 0.2631 - val_accuracy: 0.9141
# Epoch 25/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2269 - accuracy: 0.9222 - val_loss: 0.2675 - val_accuracy: 0.9070
# Epoch 26/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2211 - accuracy: 0.9256 - val_loss: 0.2547 - val_accuracy: 0.9180
# Epoch 27/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2164 - accuracy: 0.9258 - val_loss: 0.2461 - val_accuracy: 0.9176
# Epoch 28/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2110 - accuracy: 0.9270 - val_loss: 0.2499 - val_accuracy: 0.9176
# Epoch 29/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2075 - accuracy: 0.9287 - val_loss: 0.2850 - val_accuracy: 0.9062
# Epoch 30/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2012 - accuracy: 0.9318 - val_loss: 0.2667 - val_accuracy: 0.9092
# Epoch 31/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1995 - accuracy: 0.9340 - val_loss: 0.2646 - val_accuracy: 0.9112

# %%
accuracy_measures_weight_init = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Weights Initializers")

# %% [markdown]
# Both random_normal and random_uniform have similar high accuracy but random_normal completed faster. Hence, I will simply choose the random_normal as weight initializer.

# %%
model_config['weights_initializer'] = 'random_normal'

# %% [markdown]
# ## Tuning Back Propagation

# %% [markdown]
# ### Batch Normalization
#
# Batch normalization is an important technique to vanishing and exploiting gradients during gradient descent. Batch normalization help achieve higher accuracies with lower epochs, hence is also an optimization technique.
#
# *This is no longer necessary because Scaler was already applied during data preparation.*

# %%
'''
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64
model_config['hidden_activation'] = 'relu'
model_config['weights_initializer'] = 'random_normal'

normalization_list = ['batch','none']
for normalization in normalization_list:

  custom_layers = []
  if normalization == 'none':
    custom_layers = [
      layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
      layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
    ];
  else:
    custom_layers = [
      layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
      layers.BatchNormalization(),
      layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
      layers.BatchNormalization(),
      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
    ];


  model_name = 'Normalization-' + normalization
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
'''
# Out:
# "\naccuracy_measures = {}\n\nmodel_config = get_base_model_config()\n# Hyperparameters:\nmodel_config['batch_size'] = 32\nmodel_config['epochs'] = 50\n# Number of layers: 2\n# Number of nodes per each layer: 128 64\nmodel_config['hidden_activation'] = 'relu'\nmodel_config['weights_initializer'] = 'random_normal'\n\nnormalization_list = ['batch','none']\nfor normalization in normalization_list:\n\n  custom_layers = []\n  if normalization == 'none':\n    custom_layers = [\n      layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),\n      layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),\n      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])\n    ];  \n  else:\n    custom_layers = [\n      layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),\n      layers.BatchNormalization(),\n      layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),\n      layers.BatchNormalization(),\n      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])\n    ];\n\n\n  model_name = 'Normalization-' + normalization\n  model_config['model_name'] = model_name\n  model_config['custom_layers'].clear()\n  model_config['custom_layers'].extend(custom_layers)\n\n  history = create_and_run_model(model_config, X_train, y_train_dummy)\n  plot_learning_curves(history, model_name)\n  accuracy_measures[model_name] = history.history['accuracy']\n"

# %%
#accuracy_measures_normalization = accuracy_measures.copy()

# %%
#plot_accuracy_measures(accuracy_measures, "Compare Normalization Techniques")

# %% [markdown]
# The model with Batch normalization starts with higher accuracy and faster to stabilize and complete compared to the other model without normalization.

# %% [markdown]
# ### Optimizers
# Optimizer are key tools, that help gradient descent, achieve faster results. Optimizers are algorithms, that helps speed up the training process.

# %%
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64
model_config['hidden_activation'] = 'relu'
model_config['weights_initializer'] = 'random_normal'
# Batch Normalization: not added

optimizer_list = ['sgd','rmsprop','adam','adagrad']

for optimizer in optimizer_list:

  model_config['optimizer'] = optimizer

  custom_layers = [
    layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
    layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
    layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];

  model_name = 'Optimizer-' + optimizer
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Optimizer-sgd"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_104 (Dense)           (None, 128)               6656
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_105 (Dense)           (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_106 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 5s 5ms/step - loss: 0.5700 - accuracy: 0.7959 - val_loss: 0.4662 - val_accuracy: 0.8432
# Epoch 2/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4093 - accuracy: 0.8571 - val_loss: 0.5032 - val_accuracy: 0.8296
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3567 - accuracy: 0.8743 - val_loss: 0.4520 - val_accuracy: 0.8329
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3172 - accuracy: 0.8912 - val_loss: 0.3210 - val_accuracy: 0.8927
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2905 - accuracy: 0.8997 - val_loss: 0.3591 - val_accuracy: 0.8760
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2771 - accuracy: 0.9038 - val_loss: 0.3271 - val_accuracy: 0.8937
# Epoch 7/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2647 - accuracy: 0.9086 - val_loss: 0.3045 - val_accuracy: 0.8982
# Epoch 8/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2454 - accuracy: 0.9152 - val_loss: 0.3326 - val_accuracy: 0.8884
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2363 - accuracy: 0.9188 - val_loss: 0.2534 - val_accuracy: 0.9208
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2276 - accuracy: 0.9227 - val_loss: 0.2612 - val_accuracy: 0.9180
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2222 - accuracy: 0.9247 - val_loss: 0.4140 - val_accuracy: 0.8772
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2196 - accuracy: 0.9250 - val_loss: 0.3316 - val_accuracy: 0.8917
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2105 - accuracy: 0.9277 - val_loss: 0.2872 - val_accuracy: 0.9114
# Epoch 14/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2065 - accuracy: 0.9296 - val_loss: 0.3915 - val_accuracy: 0.8636
# Model: "Optimizer-rmsprop"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_107 (Dense)           (None, 128)               6656
#
#  batch_normalization_4 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_108 (Dense)           (None, 64)                8256
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_109 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5820 - accuracy: 0.7882 - val_loss: 0.5064 - val_accuracy: 0.8268
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4032 - accuracy: 0.8566 - val_loss: 0.4659 - val_accuracy: 0.8373
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3511 - accuracy: 0.8754 - val_loss: 0.4396 - val_accuracy: 0.8520
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3081 - accuracy: 0.8902 - val_loss: 0.3286 - val_accuracy: 0.8886
# Epoch 5/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2907 - accuracy: 0.8998 - val_loss: 0.3870 - val_accuracy: 0.8634
# Epoch 6/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2735 - accuracy: 0.9039 - val_loss: 0.2757 - val_accuracy: 0.9072
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2596 - accuracy: 0.9094 - val_loss: 0.3226 - val_accuracy: 0.8858
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2443 - accuracy: 0.9138 - val_loss: 0.2956 - val_accuracy: 0.8988
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2372 - accuracy: 0.9175 - val_loss: 0.2771 - val_accuracy: 0.9039
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2252 - accuracy: 0.9219 - val_loss: 0.3808 - val_accuracy: 0.8732
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2247 - accuracy: 0.9230 - val_loss: 0.3319 - val_accuracy: 0.8878
# Model: "Optimizer-adam"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_110 (Dense)           (None, 128)               6656
#
#  batch_normalization_6 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_111 (Dense)           (None, 64)                8256
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_112 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 4s 4ms/step - loss: 0.5813 - accuracy: 0.7883 - val_loss: 0.5069 - val_accuracy: 0.8078
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4064 - accuracy: 0.8539 - val_loss: 0.4002 - val_accuracy: 0.8605
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3519 - accuracy: 0.8726 - val_loss: 0.4313 - val_accuracy: 0.8498
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3141 - accuracy: 0.8892 - val_loss: 0.3972 - val_accuracy: 0.8701
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2947 - accuracy: 0.8990 - val_loss: 0.4262 - val_accuracy: 0.8565
# Epoch 6/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2738 - accuracy: 0.9059 - val_loss: 0.2757 - val_accuracy: 0.9049
# Epoch 7/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2631 - accuracy: 0.9081 - val_loss: 0.3223 - val_accuracy: 0.8868
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2439 - accuracy: 0.9160 - val_loss: 0.3016 - val_accuracy: 0.8960
# Epoch 9/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2390 - accuracy: 0.9177 - val_loss: 0.2563 - val_accuracy: 0.9123
# Epoch 10/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2307 - accuracy: 0.9217 - val_loss: 0.3231 - val_accuracy: 0.8878
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2238 - accuracy: 0.9232 - val_loss: 0.4896 - val_accuracy: 0.8512
# Epoch 12/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.2177 - accuracy: 0.9253 - val_loss: 0.3393 - val_accuracy: 0.8866
# Epoch 13/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2108 - accuracy: 0.9286 - val_loss: 0.2225 - val_accuracy: 0.9255
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2019 - accuracy: 0.9302 - val_loss: 0.2598 - val_accuracy: 0.9141
# Epoch 15/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2009 - accuracy: 0.9307 - val_loss: 0.2758 - val_accuracy: 0.9100
# Epoch 16/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1947 - accuracy: 0.9343 - val_loss: 0.2741 - val_accuracy: 0.9072
# Epoch 17/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.1873 - accuracy: 0.9352 - val_loss: 0.4647 - val_accuracy: 0.8414
# Epoch 18/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1852 - accuracy: 0.9362 - val_loss: 0.2560 - val_accuracy: 0.9165
# Model: "Optimizer-adagrad"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_113 (Dense)           (None, 128)               6656
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_114 (Dense)           (None, 64)                8256
#
#  batch_normalization_9 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_115 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 0.8523 - accuracy: 0.6952 - val_loss: 0.7478 - val_accuracy: 0.7643
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6586 - accuracy: 0.7715 - val_loss: 0.5871 - val_accuracy: 0.7925
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6020 - accuracy: 0.7911 - val_loss: 0.5413 - val_accuracy: 0.8101
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5607 - accuracy: 0.8078 - val_loss: 0.5132 - val_accuracy: 0.8282
# Epoch 5/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.5330 - accuracy: 0.8201 - val_loss: 0.4918 - val_accuracy: 0.8292
# Epoch 6/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.5170 - accuracy: 0.8252 - val_loss: 0.4728 - val_accuracy: 0.8388
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4977 - accuracy: 0.8325 - val_loss: 0.4602 - val_accuracy: 0.8449
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4836 - accuracy: 0.8369 - val_loss: 0.4478 - val_accuracy: 0.8494
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4766 - accuracy: 0.8363 - val_loss: 0.4387 - val_accuracy: 0.8534
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4622 - accuracy: 0.8428 - val_loss: 0.4291 - val_accuracy: 0.8597
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4525 - accuracy: 0.8448 - val_loss: 0.4219 - val_accuracy: 0.8622
# Epoch 12/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4465 - accuracy: 0.8481 - val_loss: 0.4140 - val_accuracy: 0.8654
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4368 - accuracy: 0.8538 - val_loss: 0.4091 - val_accuracy: 0.8675
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4325 - accuracy: 0.8551 - val_loss: 0.4034 - val_accuracy: 0.8679
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4257 - accuracy: 0.8574 - val_loss: 0.3968 - val_accuracy: 0.8699
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4159 - accuracy: 0.8601 - val_loss: 0.3901 - val_accuracy: 0.8766
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4131 - accuracy: 0.8622 - val_loss: 0.3868 - val_accuracy: 0.8695
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4081 - accuracy: 0.8635 - val_loss: 0.3824 - val_accuracy: 0.8728
# Epoch 19/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4031 - accuracy: 0.8655 - val_loss: 0.3776 - val_accuracy: 0.8772
# Epoch 20/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3975 - accuracy: 0.8647 - val_loss: 0.3753 - val_accuracy: 0.8787
# Epoch 21/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3924 - accuracy: 0.8702 - val_loss: 0.3706 - val_accuracy: 0.8779
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3897 - accuracy: 0.8709 - val_loss: 0.3677 - val_accuracy: 0.8813
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3835 - accuracy: 0.8722 - val_loss: 0.3642 - val_accuracy: 0.8803
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3781 - accuracy: 0.8738 - val_loss: 0.3602 - val_accuracy: 0.8811
# Epoch 25/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3771 - accuracy: 0.8746 - val_loss: 0.3564 - val_accuracy: 0.8833
# Epoch 26/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3727 - accuracy: 0.8774 - val_loss: 0.3540 - val_accuracy: 0.8835
# Epoch 27/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3706 - accuracy: 0.8768 - val_loss: 0.3532 - val_accuracy: 0.8844
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3656 - accuracy: 0.8772 - val_loss: 0.3485 - val_accuracy: 0.8848
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3687 - accuracy: 0.8776 - val_loss: 0.3496 - val_accuracy: 0.8860
# Epoch 30/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3631 - accuracy: 0.8801 - val_loss: 0.3444 - val_accuracy: 0.8862
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3627 - accuracy: 0.8771 - val_loss: 0.3411 - val_accuracy: 0.8880
# Epoch 32/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3563 - accuracy: 0.8810 - val_loss: 0.3397 - val_accuracy: 0.8893
# Epoch 33/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3548 - accuracy: 0.8827 - val_loss: 0.3385 - val_accuracy: 0.8909
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3526 - accuracy: 0.8844 - val_loss: 0.3367 - val_accuracy: 0.8882
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3469 - accuracy: 0.8846 - val_loss: 0.3326 - val_accuracy: 0.8893
# Epoch 36/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3469 - accuracy: 0.8858 - val_loss: 0.3322 - val_accuracy: 0.8905
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3441 - accuracy: 0.8847 - val_loss: 0.3300 - val_accuracy: 0.8907
# Epoch 38/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3439 - accuracy: 0.8866 - val_loss: 0.3287 - val_accuracy: 0.8909

# %%
accuracy_measures_optimizer = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Optimizers")

# %% [markdown]
# The result is very close, but I will simply use adam for the optimizer.

# %%
model_config['optimizer'] = 'rmsprop'

# %% [markdown]
# ### Learning Rates
#
# Learning rate is the rate at  which the weights will change in response to the estimated error. It is the speed at which the model is expected to learn from the training data and adjust its weights. Learning rates work in conjunction with the optimizer.

# %%
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64
model_config['hidden_activation'] = 'relu'
model_config['weights_initializer'] = 'random_normal'
# Batch Normalization: added BatchNormalization between the layers
model_config['optimizer'] = 'rmsprop'

learning_rate_list = [0.001, 0.005, 0.01, 0.1, 0.5]

for learning_rate in learning_rate_list:

  model_config['learning_rate'] = learning_rate

  custom_layers = [
    layers.Dense(128, kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
    layers.BatchNormalization(),
    layers.Dense(64,  kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
    layers.BatchNormalization(),
    layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];

  model_name = 'Learning-Rate-' + str(learning_rate)
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)
  accuracy_measures[model_name] = history.history['accuracy']
# Out:
# Model: "Learning-Rate-0.001"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 128)               6656
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_23 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5715 - accuracy: 0.7944 - val_loss: 0.4764 - val_accuracy: 0.8361
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3979 - accuracy: 0.8608 - val_loss: 0.4688 - val_accuracy: 0.8304
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3453 - accuracy: 0.8777 - val_loss: 0.3931 - val_accuracy: 0.8634
# Epoch 4/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3084 - accuracy: 0.8932 - val_loss: 0.3528 - val_accuracy: 0.8721
# Epoch 5/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2878 - accuracy: 0.8994 - val_loss: 0.3723 - val_accuracy: 0.8778
# Epoch 6/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2722 - accuracy: 0.9054 - val_loss: 0.3030 - val_accuracy: 0.8862
# Epoch 7/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2621 - accuracy: 0.9084 - val_loss: 0.3224 - val_accuracy: 0.8897
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2479 - accuracy: 0.9137 - val_loss: 0.2885 - val_accuracy: 0.9009
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2369 - accuracy: 0.9205 - val_loss: 0.3511 - val_accuracy: 0.8821
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2278 - accuracy: 0.9205 - val_loss: 0.3429 - val_accuracy: 0.8862
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2203 - accuracy: 0.9250 - val_loss: 0.3357 - val_accuracy: 0.8886
# Epoch 12/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.2257 - accuracy: 0.9222 - val_loss: 0.3600 - val_accuracy: 0.8679
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2094 - accuracy: 0.9276 - val_loss: 0.3165 - val_accuracy: 0.8950
# Model: "Learning-Rate-0.005"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 128)               6656
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_26 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6342 - accuracy: 0.7679 - val_loss: 0.5936 - val_accuracy: 0.7852
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4682 - accuracy: 0.8315 - val_loss: 0.5618 - val_accuracy: 0.8054
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4234 - accuracy: 0.8473 - val_loss: 0.5272 - val_accuracy: 0.8137
# Epoch 4/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3809 - accuracy: 0.8651 - val_loss: 0.3644 - val_accuracy: 0.8831
# Epoch 5/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3615 - accuracy: 0.8711 - val_loss: 0.6567 - val_accuracy: 0.7893
# Epoch 6/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3438 - accuracy: 0.8776 - val_loss: 0.5030 - val_accuracy: 0.8263
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3345 - accuracy: 0.8823 - val_loss: 0.3196 - val_accuracy: 0.8825
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3111 - accuracy: 0.8905 - val_loss: 0.3617 - val_accuracy: 0.8738
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3034 - accuracy: 0.8922 - val_loss: 0.5279 - val_accuracy: 0.8186
# Model: "Learning-Rate-0.01"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 128)               6656
#
#  batch_normalization_4 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_29 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 5s 6ms/step - loss: 0.6735 - accuracy: 0.7566 - val_loss: 0.8656 - val_accuracy: 0.7307
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4933 - accuracy: 0.8229 - val_loss: 0.6316 - val_accuracy: 0.8033
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4414 - accuracy: 0.8402 - val_loss: 0.3907 - val_accuracy: 0.8652
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4081 - accuracy: 0.8526 - val_loss: 0.6194 - val_accuracy: 0.7938
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3853 - accuracy: 0.8627 - val_loss: 0.4936 - val_accuracy: 0.8310
# Epoch 6/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3762 - accuracy: 0.8682 - val_loss: 0.3973 - val_accuracy: 0.8675
# Epoch 7/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3614 - accuracy: 0.8718 - val_loss: 0.4337 - val_accuracy: 0.8467
# Epoch 8/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.3434 - accuracy: 0.8781 - val_loss: 0.3695 - val_accuracy: 0.8742
# Epoch 9/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3360 - accuracy: 0.8819 - val_loss: 0.3556 - val_accuracy: 0.8827
# Epoch 10/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3250 - accuracy: 0.8867 - val_loss: 0.4213 - val_accuracy: 0.8498
# Epoch 11/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3161 - accuracy: 0.8881 - val_loss: 0.7955 - val_accuracy: 0.7669
# Epoch 12/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3112 - accuracy: 0.8905 - val_loss: 0.4393 - val_accuracy: 0.8540
# Epoch 13/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3019 - accuracy: 0.8924 - val_loss: 0.4039 - val_accuracy: 0.8707
# Epoch 14/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2939 - accuracy: 0.8970 - val_loss: 0.3412 - val_accuracy: 0.8850
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2954 - accuracy: 0.8966 - val_loss: 0.4126 - val_accuracy: 0.8493
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2931 - accuracy: 0.8995 - val_loss: 0.3615 - val_accuracy: 0.8838
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2813 - accuracy: 0.9009 - val_loss: 0.3893 - val_accuracy: 0.8638
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2840 - accuracy: 0.8987 - val_loss: 0.2995 - val_accuracy: 0.8945
# Epoch 19/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2759 - accuracy: 0.9053 - val_loss: 0.3123 - val_accuracy: 0.8966
# Epoch 20/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.2846 - accuracy: 0.9014 - val_loss: 0.5171 - val_accuracy: 0.8404
# Epoch 21/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2752 - accuracy: 0.9065 - val_loss: 0.3923 - val_accuracy: 0.8750
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2752 - accuracy: 0.9056 - val_loss: 0.2891 - val_accuracy: 0.8964
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2692 - accuracy: 0.9102 - val_loss: 0.3532 - val_accuracy: 0.8833
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2619 - accuracy: 0.9108 - val_loss: 0.3410 - val_accuracy: 0.8842
# Model: "Learning-Rate-0.1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 128)               6656
#
#  batch_normalization_6 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_31 (Dense)            (None, 64)                8256
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_32 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 5s 6ms/step - loss: 1.0120 - accuracy: 0.6420 - val_loss: 1.6305 - val_accuracy: 0.5900
# Epoch 2/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.8302 - accuracy: 0.7045 - val_loss: 1.3560 - val_accuracy: 0.6478
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7992 - accuracy: 0.7182 - val_loss: 0.7689 - val_accuracy: 0.7474
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7406 - accuracy: 0.7368 - val_loss: 1.1276 - val_accuracy: 0.6676
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7183 - accuracy: 0.7482 - val_loss: 0.8491 - val_accuracy: 0.7311
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7044 - accuracy: 0.7540 - val_loss: 0.7293 - val_accuracy: 0.7655
# Epoch 7/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.7176 - accuracy: 0.7475 - val_loss: 1.2977 - val_accuracy: 0.7005
# Epoch 8/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.6985 - accuracy: 0.7528 - val_loss: 1.3003 - val_accuracy: 0.7207
# Epoch 9/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.7042 - accuracy: 0.7512 - val_loss: 1.2531 - val_accuracy: 0.6427
# Epoch 10/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.6569 - accuracy: 0.7661 - val_loss: 0.9085 - val_accuracy: 0.6961
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6526 - accuracy: 0.7697 - val_loss: 1.8220 - val_accuracy: 0.7313
# Model: "Learning-Rate-0.5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 128)               6656
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  batch_normalization_9 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_35 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 16005 (62.52 KB)
# Trainable params: 15621 (61.02 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 4s 4ms/step - loss: 8.1498 - accuracy: 0.4892 - val_loss: 3.7305 - val_accuracy: 0.5867
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 6.7171 - accuracy: 0.5720 - val_loss: 3.5243 - val_accuracy: 0.6000
# Epoch 3/50
# 636/636 [==============================] - 4s 7ms/step - loss: 6.4165 - accuracy: 0.5961 - val_loss: 43.6746 - val_accuracy: 0.4412
# Epoch 4/50
# 636/636 [==============================] - 4s 6ms/step - loss: 6.4115 - accuracy: 0.6115 - val_loss: 75.1494 - val_accuracy: 0.4658
# Epoch 5/50
# 636/636 [==============================] - 3s 5ms/step - loss: 6.1849 - accuracy: 0.6120 - val_loss: 4556.3374 - val_accuracy: 0.4147
# Epoch 6/50
# 636/636 [==============================] - 2s 4ms/step - loss: 5.9578 - accuracy: 0.6204 - val_loss: 201.6752 - val_accuracy: 0.6419
# Epoch 7/50
# 636/636 [==============================] - 3s 4ms/step - loss: 6.2117 - accuracy: 0.6318 - val_loss: 1185.9315 - val_accuracy: 0.7046
# Epoch 8/50
# 636/636 [==============================] - 3s 4ms/step - loss: 6.0122 - accuracy: 0.6323 - val_loss: 277.5200 - val_accuracy: 0.6215
# Epoch 9/50
# 636/636 [==============================] - 10s 15ms/step - loss: 6.2827 - accuracy: 0.6321 - val_loss: 11.1953 - val_accuracy: 0.6956
# Epoch 10/50
# 636/636 [==============================] - 3s 5ms/step - loss: 6.0392 - accuracy: 0.6431 - val_loss: 5169.5737 - val_accuracy: 0.6230
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 5.8105 - accuracy: 0.6469 - val_loss: 1168.5259 - val_accuracy: 0.6095
# Epoch 12/50
# 636/636 [==============================] - 3s 4ms/step - loss: 5.8799 - accuracy: 0.6460 - val_loss: 839.1879 - val_accuracy: 0.7248
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 5.8407 - accuracy: 0.6418 - val_loss: 40834.5664 - val_accuracy: 0.5818
# Epoch 14/50
# 636/636 [==============================] - 4s 6ms/step - loss: 6.1007 - accuracy: 0.6488 - val_loss: 3029.1484 - val_accuracy: 0.7528
# Epoch 15/50
# 636/636 [==============================] - 3s 5ms/step - loss: 5.9107 - accuracy: 0.6604 - val_loss: 678.3093 - val_accuracy: 0.3630
# Epoch 16/50
# 636/636 [==============================] - 2s 4ms/step - loss: 5.9396 - accuracy: 0.6590 - val_loss: 1592.9642 - val_accuracy: 0.7103
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 5.8000 - accuracy: 0.6614 - val_loss: 2229.1013 - val_accuracy: 0.7459
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 5.6741 - accuracy: 0.6656 - val_loss: 5373.7451 - val_accuracy: 0.6971
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 5.8361 - accuracy: 0.6663 - val_loss: 16222.5029 - val_accuracy: 0.6958

# %%
accuracy_measures_learning_rate = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Learning Rates")

# %% [markdown]
# The learning rate 0.001 is the better choice compared to other learning rates because of higher accuracy.

# %%
model_config['learning_rate'] = 0.001

# %% [markdown]
# ## Overfitting Management

# %% [markdown]
# ### Regularization
# Regularization is an important technique for managing overfitting in neural networks. Regularization algorithms provide an adjustments to the model parameters after they are updated. The adjustment reduces the variance in the model by providing a penalty when overfitting.

# %%
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64
model_config['hidden_activation'] = 'relu'
model_config['weights_initializer'] = 'random_normal'
# Batch Normalization: added BatchNormalization between the layers
model_config['optimizer'] = 'rmsprop'
model_config['learning_rate'] = 0.001

regularizer_list = ['None', 'l1','l2','l1_l2']

for regularizer in regularizer_list:
  if regularizer == 'None':
    regularizer = None

  model_config['regularizer'] = regularizer

  custom_layers = [
    layers.Dense(128, kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
    layers.Dense(64,  kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
    layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];

  model_name = 'Regularizer-' + str(regularizer)
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)

  # Used the validation accuracy
  accuracy_measures[model_name] = history.history['val_accuracy']
# Out:
# Model: "Regularizer-None"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 128)               6656
#
#  dense_37 (Dense)            (None, 64)                8256
#
#  dense_38 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params:
50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2165 - accuracy: 0.9262 - val_loss: 0.2462 - val_accuracy: 0.9165
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2107 - accuracy: 0.9264 - val_loss: 0.2466 - val_accuracy: 0.9224
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2058 - accuracy: 0.9289 - val_loss: 0.2578 - val_accuracy: 0.9137
# Epoch 28/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2036 - accuracy: 0.9308 - val_loss: 0.2307 - val_accuracy: 0.9232
# Epoch 29/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1987 - accuracy: 0.9333 - val_loss: 0.2807 - val_accuracy: 0.9086
# Epoch 30/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.1926 - accuracy: 0.9328 - val_loss: 0.2327 - val_accuracy: 0.9224
# Epoch 31/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1906 - accuracy: 0.9355 - val_loss: 0.2698 - val_accuracy: 0.9104
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1884 - accuracy: 0.9341 - val_loss: 0.2717 - val_accuracy: 0.9043
# Epoch 33/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1843 - accuracy: 0.9368 - val_loss: 0.2228 - val_accuracy: 0.9296
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1808 - accuracy: 0.9384 - val_loss: 0.2286 - val_accuracy: 0.9237
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1740 - accuracy: 0.9425 - val_loss: 0.2353 - val_accuracy: 0.9180
# Epoch 36/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1731 - accuracy: 0.9406 - val_loss: 0.2095 - val_accuracy: 0.9338
# Epoch 37/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1697 - accuracy: 0.9417 - val_loss: 0.2216 - val_accuracy: 0.9285
# Epoch 38/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1687 - accuracy: 0.9435 - val_loss: 0.2072 - val_accuracy: 0.9344
# Epoch 39/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1643 - accuracy: 0.9439 - val_loss: 0.2103 - val_accuracy: 0.9338
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1625 - accuracy: 0.9472 - val_loss: 0.1994 - val_accuracy: 0.9369
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1607 - accuracy: 0.9448 - val_loss: 0.2066 - val_accuracy: 0.9340
# Epoch 42/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.1569 - accuracy: 0.9458 - val_loss: 0.2230 - val_accuracy: 0.9285
# Epoch 43/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1542 - accuracy: 0.9464 - val_loss: 0.2093 - val_accuracy: 0.9334
# Epoch 44/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1519 - accuracy: 0.9476 - val_loss: 0.2038 - val_accuracy: 0.9334
# Epoch 45/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1484 - accuracy: 0.9509 - val_loss: 0.2405 - val_accuracy: 0.9253
# Model: "Regularizer-l1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_39 (Dense)            (None, 128)               6656
#
#  dense_40 (Dense)            (None, 64)                8256
#
#  dense_41 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.9055 - accuracy: 0.2185 - val_loss: 1.6772 - val_accuracy: 0.2140
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6791 - accuracy: 0.2175 - val_loss: 1.6776 - val_accuracy: 0.2134
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6791 - accuracy: 0.2135 - val_loss: 1.6777 - val_accuracy: 0.2140
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6791 - accuracy: 0.2133 - val_loss: 1.6776 - val_accuracy: 0.2140
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6791 - accuracy: 0.2164 - val_loss: 1.6776 - val_accuracy: 0.2140
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6791 - accuracy: 0.2157 - val_loss: 1.6776 - val_accuracy: 0.2140
# Model: "Regularizer-l2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 128)               6656
#
#  dense_43 (Dense)            (None, 64)                8256
#
#  dense_44 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.3218 - accuracy: 0.5762 - val_loss: 1.1709 - val_accuracy: 0.6352
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.1559 - accuracy: 0.6455 - val_loss: 1.1019 - val_accuracy: 0.6806
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.1057 - accuracy: 0.6614 - val_loss: 1.0673 - val_accuracy: 0.6824
# Epoch 4/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.0612 - accuracy: 0.6841 - val_loss: 1.0201 - val_accuracy: 0.6944
# Epoch 5/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.0285 - accuracy: 0.6942 - val_loss: 0.9967 - val_accuracy: 0.6997
# Epoch 6/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.9996 - accuracy: 0.7066 - val_loss: 0.9887 - val_accuracy: 0.6944
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9757 - accuracy: 0.7159 - val_loss: 0.9405 - val_accuracy: 0.7307
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9511 - accuracy: 0.7256 - val_loss: 0.9348 - val_accuracy: 0.7351
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9281 - accuracy: 0.7350 - val_loss: 0.9858 - val_accuracy: 0.6991
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.9089 - accuracy: 0.7421 - val_loss: 0.8835 - val_accuracy: 0.7528
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8924 - accuracy: 0.7475 - val_loss: 0.8637 - val_accuracy: 0.7655
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8750 - accuracy: 0.7525 - val_loss: 0.8861 - val_accuracy: 0.7404
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.8593 - accuracy: 0.7621 - val_loss: 0.8317 - val_accuracy: 0.7716
# Epoch 14/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.8432 - accuracy: 0.7677 - val_loss: 0.8298 - val_accuracy: 0.7803
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8286 - accuracy: 0.7730 - val_loss: 0.8095 - val_accuracy: 0.7740
# Epoch 16/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.8143 - accuracy: 0.7787 - val_loss: 0.8228 - val_accuracy: 0.7809
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8036 - accuracy: 0.7811 - val_loss: 0.7909 - val_accuracy: 0.7934
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7922 - accuracy: 0.7875 - val_loss: 0.8030 - val_accuracy: 0.7816
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7812 - accuracy: 0.7894 - val_loss: 0.7636 - val_accuracy: 0.7940
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7739 - accuracy: 0.7940 - val_loss: 0.7931 - val_accuracy: 0.7962
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7653 - accuracy: 0.7976 - val_loss: 0.7571 - val_accuracy: 0.7985
# Epoch 22/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.7567 - accuracy: 0.8008 - val_loss: 0.7518 - val_accuracy: 0.8035
# Epoch 23/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.7491 - accuracy: 0.8029 - val_loss: 0.7693 - val_accuracy: 0.7889
# Epoch 24/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.7408 - accuracy: 0.8094 - val_loss: 0.7260 - val_accuracy: 0.8204
# Epoch 25/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.7338 - accuracy: 0.8105 - val_loss: 0.7419 - val_accuracy: 0.7995
# Epoch 26/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.7281 - accuracy: 0.8114 - val_loss: 0.7287 - val_accuracy: 0.8121
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7222 - accuracy: 0.8138 - val_loss: 0.7057 - val_accuracy: 0.8235
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7139 - accuracy: 0.8160 - val_loss: 0.7281 - val_accuracy: 0.8090
# Epoch 29/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.7108 - accuracy: 0.8199 - val_loss: 0.7297 - val_accuracy: 0.8156
# Epoch 30/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.7040 - accuracy: 0.8193 - val_loss: 0.6969 - val_accuracy: 0.8261
# Epoch 31/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.7016 - accuracy: 0.8199 - val_loss: 0.6935 - val_accuracy: 0.8265
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6970 - accuracy: 0.8223 - val_loss: 0.7029 - val_accuracy: 0.8253
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6927 - accuracy: 0.8234 - val_loss: 0.6803 - val_accuracy: 0.8208
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6880 - accuracy: 0.8225 - val_loss: 0.6726 - val_accuracy: 0.8394
# Epoch 35/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6857 - accuracy: 0.8265 - val_loss: 0.6800 - val_accuracy: 0.8312
# Epoch 36/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6808 - accuracy: 0.8287 - val_loss: 0.6878 - val_accuracy: 0.8149
# Epoch 37/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6774 - accuracy: 0.8302 - val_loss: 0.7670 - val_accuracy: 0.7730
# Epoch 38/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6771 - accuracy: 0.8256 - val_loss: 0.6606 - val_accuracy: 0.8300
# Epoch 39/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.6724 - accuracy: 0.8292 - val_loss: 0.6562 - val_accuracy: 0.8396
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6677 - accuracy: 0.8319 - val_loss: 0.7681 - val_accuracy: 0.7795
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6647 - accuracy: 0.8332 - val_loss: 0.6943 - val_accuracy: 0.8200
# Epoch 42/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6606 - accuracy: 0.8333 - val_loss: 0.6710 - val_accuracy: 0.8375
# Epoch 43/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6592 - accuracy: 0.8327 - val_loss: 0.6531 - val_accuracy: 0.8308
# Epoch 44/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6573 - accuracy: 0.8315 - val_loss: 0.6599 - val_accuracy: 0.8253
# Model: "Regularizer-l1_l2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 128)               6656
#
#  dense_46 (Dense)            (None, 64)                8256
#
#  dense_47 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 4s 5ms/step - loss: 1.9238 - accuracy: 0.2183 - val_loss: 1.6787 - val_accuracy: 0.2140
# Epoch 2/50
# 636/636 [==============================] - 2s 4ms/step - loss: 1.6809 - accuracy: 0.2169 - val_loss: 1.6797 - val_accuracy: 0.2134
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 1.6809 - accuracy: 0.2134 - val_loss: 1.6798 - val_accuracy: 0.2140
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6809 - accuracy: 0.2147 - val_loss: 1.6797 - val_accuracy: 0.2140
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6810 - accuracy: 0.2164 - val_loss: 1.6794 - val_accuracy: 0.2140
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.6809 - accuracy: 0.2150 - val_loss: 1.6796 - val_accuracy: 0.2140

# %%
accuracy_measures_regularizer = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Regularizers")

# %% [markdown]
# The l2 regularizer produce better accuracy and stability.

# %%
model_config['regularizer'] = None

# %% [markdown]
# ### Dropout
# Dropout works during forward propagation. By default, during forward propagation, the  output of each node in the layer is sent every node in the next layer. When using dropout, the outputs of some of the nodes in the layer are dropped randomly.

# %%
accuracy_measures = {}

model_config = get_base_model_config()
# Hyperparameters:
model_config['batch_size'] = 32
model_config['epochs'] = 50
# Number of layers: 2
# Number of nodes per each layer: 128 64
model_config['hidden_activation'] = 'relu'
model_config['weights_initializer'] = 'random_normal'
# Batch Normalization: added BatchNormalization between the layers
model_config['optimizer'] = 'rmsprop'
model_config['learning_rate'] = 0.001
model_config['regularizer'] = None
model_config['dropout_rate'] = 0.0

dropout_list = [0.0, 0.001, 0.1, 0.2, 0.5]

for dropout in dropout_list:

  model_config['dropout_rate'] = dropout

  custom_layers = []

  if model_config['dropout_rate'] > 0.0:
    custom_layers = [
      layers.Dense(128, kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
      layers.Dropout(model_config['dropout_rate']),
      layers.Dense(64,  kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
      layers.Dropout(model_config['dropout_rate']),
      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
    ];
  else:
    custom_layers = [
      layers.Dense(128, kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
      layers.Dense(64,  kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
      layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
    ];

  model_name = 'Dropout-' + str(dropout)
  model_config['model_name'] = model_name
  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  history = create_and_run_model(model_config, X_train, y_train_dummy)
  plot_learning_curves(history, model_name)

  # Used the validation accuracy
  accuracy_measures[model_name] = history.history['val_accuracy']
# Out:
# Model: "Dropout-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 128)               6656
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  dense_50 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 4s 5ms/step - loss: 1.0061 - accuracy: 0.6366 - val_loss: 0.7850 - val_accuracy: 0.7083
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7238 - accuracy: 0.7321 - val_loss: 0.6520 - val_accuracy: 0.7665
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6070 - accuracy: 0.7732 - val_loss: 0.5577 - val_accuracy: 0.7989
# Epoch 4/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.5201 - accuracy: 0.8089 - val_loss: 0.4780 - val_accuracy: 0.8221
# Epoch 5/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4660 - accuracy: 0.8309 - val_loss: 0.4680 - val_accuracy: 0.8241
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4288 - accuracy: 0.8461 - val_loss: 0.4083 - val_accuracy: 0.8585
# Epoch 7/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.4006 - accuracy: 0.8573 - val_loss: 0.3846 - val_accuracy: 0.8626
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3777 - accuracy: 0.8664 - val_loss: 0.3776 - val_accuracy: 0.8719
# Epoch 9/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3594 - accuracy: 0.8708 - val_loss: 0.4192 - val_accuracy: 0.8502
# Epoch 10/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3433 - accuracy: 0.8807 - val_loss: 0.3612 - val_accuracy: 0.8770
# Epoch 11/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3298 - accuracy: 0.8839 - val_loss: 0.3450 - val_accuracy: 0.8770
# Epoch 12/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.3193 - accuracy: 0.8874 - val_loss: 0.3151 - val_accuracy: 0.8943
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3064 - accuracy: 0.8911 - val_loss: 0.3117 - val_accuracy: 0.8913
# Epoch 14/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2966 - accuracy: 0.8951 - val_loss: 0.3160 - val_accuracy: 0.8976
# Epoch 15/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2869 - accuracy: 0.8978 - val_loss: 0.3298 - val_accuracy: 0.8819
# Epoch 16/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2764 - accuracy: 0.9027 - val_loss: 0.3297 - val_accuracy: 0.8840
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2692 - accuracy: 0.9043 - val_loss: 0.3161 - val_accuracy: 0.8945
# Epoch 18/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2605 - accuracy: 0.9070 - val_loss: 0.2840 - val_accuracy: 0.9004
# Epoch 19/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2542 - accuracy: 0.9111 - val_loss: 0.3142 - val_accuracy: 0.8984
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2451 - accuracy: 0.9137 - val_loss: 0.2983 - val_accuracy: 0.8945
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2404 - accuracy: 0.9169 - val_loss: 0.2602 - val_accuracy: 0.9110
# Epoch 22/50
# 636/636 [==============================] - 1s 2ms/step - loss: 0.2335 - accuracy: 0.9168 - val_loss: 0.2577 - val_accuracy: 0.9155
# Epoch 23/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2263 - accuracy: 0.9211 - val_loss: 0.2643 - val_accuracy: 0.9104
# Epoch 24/50
# 636/636 [==============================] - 2s 2ms/step - loss: 0.2213 - accuracy: 0.9238 - val_loss: 0.2433 - val_accuracy: 0.9180
# Epoch 25/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2176 - accuracy: 0.9255 - val_loss: 0.2455 - val_accuracy: 0.9167
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2123 - accuracy: 0.9264 - val_loss: 0.2406 - val_accuracy: 0.9230
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2054 - accuracy: 0.9288 - val_loss: 0.2427 - val_accuracy: 0.9161
# Epoch 28/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2032 - accuracy: 0.9294 - val_loss: 0.2314 - val_accuracy: 0.9239
# Epoch 29/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1999 - accuracy: 0.9317 - val_loss: 0.3423 - val_accuracy: 0.8872
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1947 - accuracy: 0.9330 - val_loss: 0.2373 - val_accuracy: 0.9210
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1931 - accuracy: 0.9338 - val_loss: 0.2526 - val_accuracy: 0.9175
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1905 - accuracy: 0.9344 - val_loss: 0.2663 - val_accuracy: 0.9072
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1861 - accuracy: 0.9346 - val_loss: 0.2543 - val_accuracy: 0.9159
# Model: "Dropout-0.001"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_51 (Dense)            (None, 128)               6656
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_52 (Dense)            (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_53 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.9823 - accuracy: 0.6452 - val_loss: 0.7756 - val_accuracy: 0.7079
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7145 - accuracy: 0.7369 - val_loss: 0.6407 - val_accuracy: 0.7661
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6007 - accuracy: 0.7765 - val_loss: 0.5549 - val_accuracy: 0.7958
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5182 - accuracy: 0.8097 - val_loss: 0.4793 - val_accuracy: 0.8233
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4673 - accuracy: 0.8303 - val_loss: 0.4652 - val_accuracy: 0.8280
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4302 - accuracy: 0.8450 - val_loss: 0.4046 - val_accuracy: 0.8620
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4016 - accuracy: 0.8573 - val_loss: 0.3894 - val_accuracy: 0.8669
# Epoch 8/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3775 - accuracy: 0.8663 - val_loss: 0.3728 - val_accuracy: 0.8742
# Epoch 9/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3588 - accuracy: 0.8717 - val_loss: 0.4015 - val_accuracy: 0.8581
# Epoch 10/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3420 - accuracy: 0.8783 - val_loss: 0.3633 - val_accuracy: 0.8821
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3261 - accuracy: 0.8839 - val_loss: 0.3322 - val_accuracy: 0.8868
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3135 - accuracy: 0.8904 - val_loss: 0.3159 - val_accuracy: 0.8929
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3004 - accuracy: 0.8932 - val_loss: 0.3083 - val_accuracy: 0.8958
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2897 - accuracy: 0.8967 - val_loss: 0.2979 - val_accuracy: 0.9004
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2784 - accuracy: 0.9006 - val_loss: 0.3295 - val_accuracy: 0.8842
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2696 - accuracy: 0.9044 - val_loss: 0.3141 - val_accuracy: 0.8976
# Epoch 17/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2617 - accuracy: 0.9068 - val_loss: 0.3020 - val_accuracy: 0.8998
# Epoch 18/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2535 - accuracy: 0.9117 - val_loss: 0.2781 - val_accuracy: 0.9043
# Epoch 19/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2483 - accuracy: 0.9130 - val_loss: 0.3250 - val_accuracy: 0.8925
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2401 - accuracy: 0.9170 - val_loss: 0.3295 - val_accuracy: 0.8854
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2342 - accuracy: 0.9187 - val_loss: 0.2581 - val_accuracy: 0.9133
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2304 - accuracy: 0.9195 - val_loss: 0.2382 - val_accuracy: 0.9220
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2229 - accuracy: 0.9233 - val_loss: 0.2504 - val_accuracy: 0.9147
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2173 - accuracy: 0.9243 - val_loss: 0.2454 - val_accuracy: 0.9202
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2149 - accuracy: 0.9282 - val_loss: 0.2474 - val_accuracy: 0.9133
# Epoch 26/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2108 - accuracy: 0.9277 - val_loss: 0.2329 - val_accuracy: 0.9255
# Epoch 27/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2037 - accuracy: 0.9280 - val_loss: 0.2428 - val_accuracy: 0.9214
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2006 - accuracy: 0.9312 - val_loss: 0.2382 - val_accuracy: 0.9220
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1968 - accuracy: 0.9331 - val_loss: 0.2668 - val_accuracy: 0.9108
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1914 - accuracy: 0.9354 - val_loss: 0.2540 - val_accuracy: 0.9153
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1927 - accuracy: 0.9349 - val_loss: 0.2309 - val_accuracy: 0.9273
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1866 - accuracy: 0.9364 - val_loss: 0.2631 - val_accuracy: 0.9135
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1842 - accuracy: 0.9379 - val_loss: 0.2283 - val_accuracy: 0.9290
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1811 - accuracy: 0.9390 - val_loss: 0.2374 - val_accuracy: 0.9220
# Epoch 35/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1764 - accuracy: 0.9411 - val_loss: 0.2352 - val_accuracy: 0.9253
# Epoch 36/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1727 - accuracy: 0.9423 - val_loss: 0.2222 - val_accuracy: 0.9318
# Epoch 37/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1696 - accuracy: 0.9409 - val_loss: 0.2382 - val_accuracy: 0.9279
# Epoch 38/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1685 - accuracy: 0.9436 - val_loss: 0.2068 - val_accuracy: 0.9387
# Epoch 39/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1629 - accuracy: 0.9447 - val_loss: 0.2201 - val_accuracy: 0.9324
# Epoch 40/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1619 - accuracy: 0.9467 - val_loss: 0.2286 - val_accuracy: 0.9314
# Epoch 41/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1604 - accuracy: 0.9440 - val_loss: 0.2528 - val_accuracy: 0.9228
# Epoch 42/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.1572 - accuracy: 0.9461 - val_loss: 0.2172 - val_accuracy: 0.9334
# Epoch 43/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.1545 - accuracy: 0.9471 - val_loss: 0.2111 - val_accuracy: 0.9381
# Model: "Dropout-0.1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 128)               6656
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_55 (Dense)            (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_56 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.0170 - accuracy: 0.6306 - val_loss: 0.7682 - val_accuracy: 0.7217
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7339 - accuracy: 0.7336 - val_loss: 0.6451 - val_accuracy: 0.7689
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6305 - accuracy: 0.7702 - val_loss: 0.5553 - val_accuracy: 0.7978
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5512 - accuracy: 0.8005 - val_loss: 0.4850 - val_accuracy: 0.8241
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4974 - accuracy: 0.8207 - val_loss: 0.4558 - val_accuracy: 0.8322
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4601 - accuracy: 0.8342 - val_loss: 0.4146 - val_accuracy: 0.8612
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4323 - accuracy: 0.8466 - val_loss: 0.3918 - val_accuracy: 0.8646
# Epoch 8/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.4073 - accuracy: 0.8558 - val_loss: 0.3778 - val_accuracy: 0.8652
# Epoch 9/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3906 - accuracy: 0.8618 - val_loss: 0.3888 - val_accuracy: 0.8634
# Epoch 10/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.3723 - accuracy: 0.8708 - val_loss: 0.3448 - val_accuracy: 0.8878
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3611 - accuracy: 0.8723 - val_loss: 0.3373 - val_accuracy: 0.8892
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3496 - accuracy: 0.8776 - val_loss: 0.3234 - val_accuracy: 0.8917
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3410 - accuracy: 0.8783 - val_loss: 0.3058 - val_accuracy: 0.8958
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3293 - accuracy: 0.8836 - val_loss: 0.3220 - val_accuracy: 0.8858
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3195 - accuracy: 0.8862 - val_loss: 0.3091 - val_accuracy: 0.8911
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3123 - accuracy: 0.8902 - val_loss: 0.2904 - val_accuracy: 0.9013
# Epoch 17/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3107 - accuracy: 0.8918 - val_loss: 0.2983 - val_accuracy: 0.8996
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3003 - accuracy: 0.8925 - val_loss: 0.2816 - val_accuracy: 0.9049
# Epoch 19/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2940 - accuracy: 0.8982 - val_loss: 0.3100 - val_accuracy: 0.8970
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2884 - accuracy: 0.8990 - val_loss: 0.2862 - val_accuracy: 0.9037
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2875 - accuracy: 0.8995 - val_loss: 0.2663 - val_accuracy: 0.9102
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2782 - accuracy: 0.9038 - val_loss: 0.2637 - val_accuracy: 0.9114
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2735 - accuracy: 0.9061 - val_loss: 0.2715 - val_accuracy: 0.9084
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2700 - accuracy: 0.9094 - val_loss: 0.2579 - val_accuracy: 0.9188
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2669 - accuracy: 0.9106 - val_loss: 0.2550 - val_accuracy: 0.9155
# Epoch 26/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2654 - accuracy: 0.9104 - val_loss: 0.2560 - val_accuracy: 0.9180
# Epoch 27/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2588 - accuracy: 0.9119 - val_loss: 0.2609 - val_accuracy: 0.9159
# Epoch 28/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2572 - accuracy: 0.9119 - val_loss: 0.2491 - val_accuracy: 0.9216
# Epoch 29/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2528 - accuracy: 0.9134 - val_loss: 0.3246 - val_accuracy: 0.8925
# Epoch 30/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2518 - accuracy: 0.9148 - val_loss: 0.2465 - val_accuracy: 0.9233
# Epoch 31/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2524 - accuracy: 0.9150 - val_loss: 0.2424 - val_accuracy: 0.9257
# Epoch 32/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2450 - accuracy: 0.9177 - val_loss: 0.2586 - val_accuracy: 0.9200
# Epoch 33/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2410 - accuracy: 0.9185 - val_loss: 0.2552 - val_accuracy: 0.9218
# Epoch 34/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2417 - accuracy: 0.9198 - val_loss: 0.2412 - val_accuracy: 0.9218
# Epoch 35/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2376 - accuracy: 0.9237 - val_loss: 0.2423 - val_accuracy: 0.9222
# Epoch 36/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.2381 - accuracy: 0.9214 - val_loss: 0.2327 - val_accuracy: 0.9255
# Model: "Dropout-0.2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_57 (Dense)            (None, 128)               6656
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_58 (Dense)            (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_59 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 4ms/step - loss: 1.0354 - accuracy: 0.6218 - val_loss: 0.7838 - val_accuracy: 0.7107
# Epoch 2/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.7680 - accuracy: 0.7234 - val_loss: 0.6619 - val_accuracy: 0.7581
# Epoch 3/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6562 - accuracy: 0.7611 - val_loss: 0.5656 - val_accuracy: 0.7970
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5779 - accuracy: 0.7886 - val_loss: 0.4988 - val_accuracy: 0.8135
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.8095 - val_loss: 0.4659 - val_accuracy: 0.8280
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4924 - accuracy: 0.8232 - val_loss: 0.4213 - val_accuracy: 0.8506
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4610 - accuracy: 0.8358 - val_loss: 0.4065 - val_accuracy: 0.8595
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4335 - accuracy: 0.8475 - val_loss: 0.3784 - val_accuracy: 0.8669
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4131 - accuracy: 0.8536 - val_loss: 0.3784 - val_accuracy: 0.8687
# Epoch 10/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3983 - accuracy: 0.8615 - val_loss: 0.3608 - val_accuracy: 0.8797
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3908 - accuracy: 0.8638 - val_loss: 0.3442 - val_accuracy: 0.8803
# Epoch 12/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3788 - accuracy: 0.8697 - val_loss: 0.3436 - val_accuracy: 0.8864
# Epoch 13/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3690 - accuracy: 0.8719 - val_loss: 0.3208 - val_accuracy: 0.8919
# Epoch 14/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3635 - accuracy: 0.8732 - val_loss: 0.3134 - val_accuracy: 0.8986
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3528 - accuracy: 0.8780 - val_loss: 0.3301 - val_accuracy: 0.8939
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3490 - accuracy: 0.8818 - val_loss: 0.3156 - val_accuracy: 0.8958
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3489 - accuracy: 0.8829 - val_loss: 0.3085 - val_accuracy: 0.8980
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3349 - accuracy: 0.8866 - val_loss: 0.3032 - val_accuracy: 0.9004
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3332 - accuracy: 0.8856 - val_loss: 0.3259 - val_accuracy: 0.8907
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3328 - accuracy: 0.8887 - val_loss: 0.3063 - val_accuracy: 0.9011
# Epoch 21/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3265 - accuracy: 0.8893 - val_loss: 0.2900 - val_accuracy: 0.9033
# Epoch 22/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.3199 - accuracy: 0.8929 - val_loss: 0.2815 - val_accuracy: 0.9100
# Epoch 23/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3176 - accuracy: 0.8928 - val_loss: 0.2890 - val_accuracy: 0.9070
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3166 - accuracy: 0.8954 - val_loss: 0.2840 - val_accuracy: 0.9125
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3123 - accuracy: 0.8950 - val_loss: 0.2778 - val_accuracy: 0.9092
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3037 - accuracy: 0.8984 - val_loss: 0.2976 - val_accuracy: 0.9088
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3052 - accuracy: 0.9005 - val_loss: 0.2742 - val_accuracy: 0.9114
# Epoch 28/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3009 - accuracy: 0.8990 - val_loss: 0.2751 - val_accuracy: 0.9110
# Epoch 29/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.3009 - accuracy: 0.9003 - val_loss: 0.3009 - val_accuracy: 0.9041
# Model: "Dropout-0.5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 128)               6656
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_61 (Dense)            (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_62 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 2s 3ms/step - loss: 1.1645 - accuracy: 0.5609 - val_loss: 0.8423 - val_accuracy: 0.6950
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.8869 - accuracy: 0.6888 - val_loss: 0.7197 - val_accuracy: 0.7414
# Epoch 3/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.7919 - accuracy: 0.7209 - val_loss: 0.6405 - val_accuracy: 0.7777
# Epoch 4/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.7215 - accuracy: 0.7490 - val_loss: 0.5810 - val_accuracy: 0.7970
# Epoch 5/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.6767 - accuracy: 0.7657 - val_loss: 0.5380 - val_accuracy: 0.8078
# Epoch 6/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6491 - accuracy: 0.7737 - val_loss: 0.5150 - val_accuracy: 0.8231
# Epoch 7/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6231 - accuracy: 0.7859 - val_loss: 0.5062 - val_accuracy: 0.8215
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6016 - accuracy: 0.7905 - val_loss: 0.4742 - val_accuracy: 0.8310
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5915 - accuracy: 0.7983 - val_loss: 0.4829 - val_accuracy: 0.8331
# Epoch 10/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.5796 - accuracy: 0.8032 - val_loss: 0.4569 - val_accuracy: 0.8443
# Epoch 11/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5663 - accuracy: 0.8054 - val_loss: 0.4349 - val_accuracy: 0.8487
# Epoch 12/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5630 - accuracy: 0.8096 - val_loss: 0.4413 - val_accuracy: 0.8384
# Epoch 13/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5585 - accuracy: 0.8089 - val_loss: 0.4280 - val_accuracy: 0.8475
# Epoch 14/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.8150 - val_loss: 0.4231 - val_accuracy: 0.8471
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.8210 - val_loss: 0.4155 - val_accuracy: 0.8550
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5394 - accuracy: 0.8204 - val_loss: 0.4051 - val_accuracy: 0.8610
# Epoch 17/50
# 636/636 [==============================] - 2s 4ms/step - loss: 0.5337 - accuracy: 0.8224 - val_loss: 0.4066 - val_accuracy: 0.8689
# Epoch 18/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.5264 - accuracy: 0.8263 - val_loss: 0.4111 - val_accuracy: 0.8587
# Epoch 19/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.5266 - accuracy: 0.8243 - val_loss: 0.4106 - val_accuracy: 0.8589
# Epoch 20/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5265 - accuracy: 0.8273 - val_loss: 0.4137 - val_accuracy: 0.8616
# Epoch 21/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5349 - accuracy: 0.8270 - val_loss: 0.3975 - val_accuracy: 0.8595
# Epoch 22/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5242 - accuracy: 0.8275 - val_loss: 0.3903 - val_accuracy: 0.8673

# %%
accuracy_measures_dropout = accuracy_measures.copy()

# %%
plot_accuracy_measures(accuracy_measures, "Compare Dropout")

# %% [markdown]
# I will be using the dropoout rate of 0.1 since it starts on higher accuracy and it show's it is more stable compared to other drop out rates. Another possible candidate is 0.2 but it seems flakey compared to 0.1.

# %%
model_config['dropout_rate'] = 0.1

# %% [markdown]
# # Model - Evaluation

# %%
def get_best_param_model_config(model_name):
  """
  (str) -> dict

  This method returns the best hyper parameters from experiments.

  Parameters
  ----------
  model_name - The name of the model

  Returns
  ----------
  dict - The dictionary containing the best hyper parameters from experiments.
  """
  # Default model config
  model_config = get_base_model_config()

  model_config['model_name'] = model_name

  # These are the final hyperparameters that I will use in training the Models:
  # Hyperparameters:
  #model_config['batch_size'] = 32
  #model_config['epochs'] = 50
  # Number of layers: 2
  # Number of nodes per each layer: 128 64
  #model_config['hidden_activation'] = 'relu'
  #model_config['weights_initializer'] = 'random_normal'
  # Batch Normalization: added BatchNormalization between the layers
  #model_config['optimizer'] = 'adam'
  #model_config['learning_rate'] = 0.001

  #model_config['dropout_rate'] = 0.5
  #model_config = get_base_model_config()
  # Hyperparameters:
  model_config['batch_size'] = 32
  model_config['epochs'] = 50
  # Number of layers: 2
  # Number of nodes per each layer: 128 64
  model_config['hidden_activation'] = 'relu'
  model_config['weights_initializer'] = 'random_normal'
  model_config['optimizer'] = 'rmpsprop'
  model_config['learning_rate'] = 0.001
  model_config['regularizer'] = None
  model_config['dropout_rate'] = 0.1

  custom_layers = [
    layers.Dense(128, kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation'], input_dim=model_config['input_dim']),
    layers.Dropout(model_config['dropout_rate']),
    layers.Dense(64,  kernel_regularizer=model_config['regularizer'], kernel_initializer=model_config['weights_initializer'], activation=model_config['hidden_activation']),
    layers.Dropout(model_config['dropout_rate']),
    layers.Dense(model_config['output_nodes'], activation=model_config['output_activation'])
  ];

  model_config['custom_layers'].clear()
  model_config['custom_layers'].extend(custom_layers)

  # we would like to save the model starting here for evaluation.
  model_config['is_save_model'] = True

  return model_config

# %%
from keras.models import load_model

def evaluate_model(model_config, X, y):
  """
  (dict, tf.data.Dataset)

  This is a reusable function that load a previously trained model and run an evaluation.

  Parameters
  ----------
  model_config - The dictionary to use in model evaluation.
  test_ds - The test dataset to use in the evaluation.

  Returns
  ----------
  Dataframe - The Panda Dataframe containing the scores from the experiment. The scores includes the Accuracy and Loss.
  """
  model_file = str(model_config['workspace_path']) + str(model_config['model_name']) + '.h5'
  model = load_model(model_file)


  #result = model.evaluate(test_ds)

  #result_in_dict = dict(zip(model.metrics_names, result))

  #loss = result_in_dit['loss']
  #accuracy = result_in_dict['accuracy']

  #scores_df = pd.DataFrame([[accuracy, loss]], ['Score'], ['Accuracy', 'Loss'])

  #return scores_df
  test_loss, test_acc = model.evaluate(X, y, verbose=2)
  print(f"Test accuracy: {test_acc}")

# %%
# reset accuracy measures
accuracy_measures = {}

# %%
model_name = 'SCS_3546_Trained_and_Tuned_Model'
model_config = get_best_param_model_config(model_name)

model_1_history = create_and_run_model(model_config, X_train, y_train_dummy)
# Out:
# Model: "SCS_3546_Trained_and_Tuned_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_63 (Dense)            (None, 128)               6656
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_64 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_65 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 15237 (59.52 KB)
# Trainable params: 15237 (59.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 636/636 [==============================] - 3s 3ms/step - loss: 1.0125 - accuracy: 0.6256 - val_loss: 0.7777 - val_accuracy: 0.7115
# Epoch 2/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.7391 - accuracy: 0.7297 - val_loss: 0.6500 - val_accuracy: 0.7630
# Epoch 3/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.6277 - accuracy: 0.7702 - val_loss: 0.5593 - val_accuracy: 0.7964
# Epoch 4/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5504 - accuracy: 0.7995 - val_loss: 0.4902 - val_accuracy: 0.8156
# Epoch 5/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.5034 - accuracy: 0.8181 - val_loss: 0.4667 - val_accuracy: 0.8314
# Epoch 6/50
# 636/636 [==============================] - 3s 5ms/step - loss: 0.4662 - accuracy: 0.8320 - val_loss: 0.4179 - val_accuracy: 0.8565
# Epoch 7/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.4383 - accuracy: 0.8427 - val_loss: 0.3930 - val_accuracy: 0.8620
# Epoch 8/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.4148 - accuracy: 0.8524 - val_loss: 0.3838 - val_accuracy: 0.8642
# Epoch 9/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3954 - accuracy: 0.8608 - val_loss: 0.3902 - val_accuracy: 0.8630
# Epoch 10/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3756 - accuracy: 0.8682 - val_loss: 0.3555 - val_accuracy: 0.8833
# Epoch 11/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3647 - accuracy: 0.8726 - val_loss: 0.3304 - val_accuracy: 0.8856
# Epoch 12/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3517 - accuracy: 0.8774 - val_loss: 0.3197 - val_accuracy: 0.8921
# Epoch 13/50
# 636/636 [==============================] - 6s 9ms/step - loss: 0.3365 - accuracy: 0.8800 - val_loss: 0.3194 - val_accuracy: 0.8899
# Epoch 14/50
# 636/636 [==============================] - 4s 6ms/step - loss: 0.3321 - accuracy: 0.8836 - val_loss: 0.3102 - val_accuracy: 0.9013
# Epoch 15/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3204 - accuracy: 0.8882 - val_loss: 0.3023 - val_accuracy: 0.8962
# Epoch 16/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3111 - accuracy: 0.8933 - val_loss: 0.3002 - val_accuracy: 0.9027
# Epoch 17/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.3054 - accuracy: 0.8934 - val_loss: 0.3052 - val_accuracy: 0.9002
# Epoch 18/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2969 - accuracy: 0.8956 - val_loss: 0.2906 - val_accuracy: 0.9043
# Epoch 19/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2891 - accuracy: 0.8980 - val_loss: 0.3071 - val_accuracy: 0.8949
# Epoch 20/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2836 - accuracy: 0.9037 - val_loss: 0.2846 - val_accuracy: 0.9064
# Epoch 21/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2840 - accuracy: 0.9037 - val_loss: 0.2649 - val_accuracy: 0.9119
# Epoch 22/50
# 636/636 [==============================] - 3s 4ms/step - loss: 0.2799 - accuracy: 0.9041 - val_loss: 0.2605 - val_accuracy: 0.9182
# Epoch 23/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2722 - accuracy: 0.9083 - val_loss: 0.2722 - val_accuracy: 0.9066
# Epoch 24/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2703 - accuracy: 0.9089 - val_loss: 0.2534 - val_accuracy: 0.9176
# Epoch 25/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2629 - accuracy: 0.9109 - val_loss: 0.2656 - val_accuracy: 0.9098
# Epoch 26/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2613 - accuracy: 0.9123 - val_loss: 0.2568 - val_accuracy: 0.9163
# Epoch 27/50
# 636/636 [==============================] - 2s 3ms/step - loss: 0.2601 - accuracy: 0.9106 - val_loss: 0.2568 - val_accuracy: 0.9147

# %%
plot_learning_curves(model_1_history, model_name)

# %%
evaluate_model(model_config, X_test, y_test_dummy)
# Out:
# 341/341 - 1s - loss: 0.2607 - accuracy: 0.9167 - 922ms/epoch - 3ms/step
# Test accuracy: 0.9167125225067139
